# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from bertopic import BERTopic
from bertopic.vectorizers import ClassTfidfTransformer
from bertopic.dimensionality import BaseDimensionalityReduction
from sklearn.feature_extraction.text import CountVectorizer
from cuml.manifold import UMAP
from cuml.cluster import HDBSCAN
from sentence_transformers import SentenceTransformer

# %%
df_03 = pd.read_csv('data/stemmed_merged_kubu_03.csv')

# %%
indo_stopwords = [
    # Basic Indonesian stopwords
    "yang", "dan", "di", "dengan", "untuk", "dari", "ke", "pada", "ini", "itu",
    "atau", "ada", "juga", "dalam", "saya", "kamu", "anda", "mereka", "kita", "kami",
    "dia", "nya", "adalah", "akan", "oleh", "seperti", "telah", "sudah", "bisa", "dapat",
    "tidak", "tak", "jangan", "ya", "via", "yg", "dgn", "utk", "dr", "pd", "dlm", "sdh", "tdk",
    
    # Candidate names and references (since they appear in nearly every tweet)
    "ganjar", "pranowo", "mahfud", "md", "gp", "gama", "prabowo", "gibran", "megawati",
    
    # Common Balinese campaign greeting (appears frequently)
    "rahajeng", "rawuh", "bal", "bali", "dewata", "pulau",
    
    
    # Location indicators
    "indonesia", "jakarta", "jawa", "timur", "barat", "tengah", "sumatra", "utara", 
    "selatan", "kota", "daerah", "provinsi", "wilayah", "region",
]

# %%
vectorizer = CountVectorizer(
    stop_words=indo_stopwords,
    ngram_range=(1, 3),  # Keep bigrams and trigrams for political phrases
    min_df=5,            # Lower threshold to capture more specific topics
    max_df=0.7           # Stricter upper bound to remove very common terms
)

# Configure UMAP for better clustering of political content
umap_model = UMAP(
    n_neighbors=15,      # Smaller neighborhood for more specific clusters
    n_components=5,      
    min_dist=0.0,        # Adjusted for better separation
    metric='cosine',
    random_state=42
)

# More sensitive clustering for political topics
hdbscan_model = HDBSCAN(
    min_cluster_size=10,  # Smaller clusters to capture specific campaign themes
    min_samples=5,       # More lenient sample requirement
    metric='euclidean',
    cluster_selection_method='eom',
    prediction_data=True
)

# Improved c-TF-IDF weighting
ctfidf_model = ClassTfidfTransformer(
    reduce_frequent_words=True,
    bm25_weighting=True
)

embedding_model = SentenceTransformer(
    'distiluse-base-multilingual-cased-v1'
)

# Configure BERTopic for Indonesian political content
topic_model = BERTopic(
    language="multilingual",  # Keep multilingual for Indonesian
    calculate_probabilities=True,
    verbose=True,
    nr_topics=15,             # Reduced from 15 to get more focused topics
    min_topic_size=5,         # Smaller topics to capture campaign themes
    umap_model=umap_model,
    hdbscan_model=hdbscan_model,
    ctfidf_model=ctfidf_model,
    vectorizer_model=vectorizer,
    embedding_model=embedding_model,
)


# Fit the model
topics, probs = topic_model.fit_transform(df_03['full_text'].tolist())
# Out:
# [2025-06-02 15:16:02.697] [CUML] [info] build_algo set to brute_force_knn because random_state is given
# 2025-06-02 15:16:07,181 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches:   0%|          | 0/1183 [00:00<?, ?it/s]
# 2025-06-02 15:16:15,000 - BERTopic - Embedding - Completed ✓
# 2025-06-02 15:16:15,001 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2025-06-02 15:16:15,581 - BERTopic - Dimensionality - Completed ✓
# 2025-06-02 15:16:15,582 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2025-06-02 15:16:16,652 - BERTopic - Cluster - Completed ✓
# 2025-06-02 15:16:16,653 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 2025-06-02 15:16:17,085 - BERTopic - Representation - Completed ✓
# 2025-06-02 15:16:17,085 - BERTopic - Topic reduction - Reducing number of topics
# 2025-06-02 15:16:17,521 - BERTopic - Topic reduction - Reduced number of topics from 214 to 15

# %%
# Generate more intuitive topic labels for Ganjar's campaign
topic_labels = {}
for topic_id in topic_model.get_topic_info()["Topic"]:
    if topic_id == -1:
        topic_labels[topic_id] = "Outlier"
        continue
        
    # Get top words
    words = [word for word, _ in topic_model.get_topic(topic_id)[:5]]
    
    # Map topics to Ganjar campaign themes based on keywords
    if any(term in words for term in ["bal", "bali", "rahajeng", "rawuh"]):
        topic_labels[topic_id] = "Kampanye Bali"
    elif any(term in words for term in ["jawa", "tengah", "jateng", "banteng"]):
        topic_labels[topic_id] = "Basis Dukungan Jawa Tengah"
    elif any(term in words for term in ["legislatif", "eksekutif", "yudikatif", "jejak", "rekam"]):
        topic_labels[topic_id] = "Pengalaman Pemerintahan"
    elif any(term in words for term in ["fokus", "dukung", "motivasi", "kembang"]):
        topic_labels[topic_id] = "Dukungan & Motivasi"
    elif any(term in words for term in ["demokrasi", "partai", "pdip", "banteng", "merah"]):
        topic_labels[topic_id] = "Dukungan Partai PDI-P"
    elif any(term in words for term in ["dame", "hati", "adem", "damai", "sejuk"]):
        topic_labels[topic_id] = "Citra Kepemimpinan Adem"
    elif any(term in words for term in ["aspirasi", "dengar", "blusuk", "jumpa"]):
        topic_labels[topic_id] = "Pendekatan ke Masyarakat"
    elif any(term in words for term in ["tegak", "lurus", "jujur", "bersih"]):
        topic_labels[topic_id] = "Integritas & Kejujuran"
    elif any(term in words for term in ["huru", "hara", "politik", "sembuh", "luka"]):
        topic_labels[topic_id] = "Perbaikan Situasi Politik"
    elif any(term in words for term in ["penjuru", "nusantara", "kenal"]):
        topic_labels[topic_id] = "Popularitas Nasional"
    else:
        # Use the first few words as a generic label
        topic_labels[topic_id] = " & ".join(words[:3])

# Apply custom labels
topic_model.set_topic_labels(topic_labels)

# %%
# import wordcloud
from wordcloud import WordCloud

# %%
# Get the improved topic information
topic_info = topic_model.get_topic_info()
print("\nImproved Topic Information:")
print(topic_info.head(10))

# Print topics with their new labels
print("\nCampaign Themes for Ganjar-Mahfud:")
for index, row in topic_info.iterrows():
    if row["Topic"] != -1:  # Skip outlier topic
        topic_id = row["Topic"]
        words = [word[0] for word in topic_model.get_topic(topic_id)[:8]]
        print(f"Theme: {row['Name']}")
        print(f"Keywords: {', '.join(words)}")
        print(f"Document count: {row['Count']}")
        print("-" * 50)

# Create a topic distribution visualization
plt.figure(figsize=(12, 6))
topic_counts = topic_info[topic_info["Topic"] != -1]["Count"]
topic_names = [label for topic, label in topic_labels.items() if topic != -1][:len(topic_counts)]

# Plot with better color scheme
bars = plt.bar(topic_names, topic_counts, color=plt.cm.viridis(np.linspace(0, 1, len(topic_counts))))

# Add count labels on top of bars
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height + 0.5,
            f'{int(height)}', ha='center', va='bottom', fontweight='bold')

plt.xticks(rotation=45, ha="right")
plt.title("Distribution of Campaign Themes in Ganjar-Mahfud Tweets", fontsize=14, fontweight='bold')
plt.xlabel("Campaign Themes", fontsize=12)
plt.ylabel("Number of Tweets", fontsize=12)
plt.tight_layout()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# Display interactive visualizations
intertopic_map = topic_model.visualize_topics()
display(intertopic_map)

# Create hierarchical clustering visualization
hierarchy = topic_model.visualize_hierarchy()
display(hierarchy)

# Create heatmap of topic similarities
heatmap = topic_model.visualize_heatmap()
display(heatmap)

# Create word clouds for top 3 topics
plt.figure(figsize=(15, 10))
for i, topic_id in enumerate(topic_info[topic_info['Topic'] != -1]['Topic'][:3]):
    plt.subplot(1, 3, i+1)
    
    # Get topic words and weights
    words = dict(topic_model.get_topic(topic_id)[:15])
    
    # Create and display wordcloud
    wordcloud = WordCloud(width=400, height=400, background_color='white', 
                          colormap='viridis', max_words=50).generate_from_frequencies(words)
    
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.title(f"Topic: {topic_labels[topic_id]}", fontsize=12)
    plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# Improved Topic Information:
#    Topic  Count                                               Name  \
# 0     -1  15638                   -1_warga_pimpin_dukung 03_sambut
# 1      0  13092                 0_program_gratis_internet_koruptor
# 2      1   4440     1_pilih presiden_calon presiden_partai_politik
# 3      2   3409      2_kayak_pasang calon 03_calon 03_pasang calon
# 4      3    451                  3_kerja_produk_tugas_produk lokal
# 5      4    190                         4_porno_video_viral_tonton
# 6      5    146                5_strategi_strategis_terobos_proyek
# 7      6    119               6_mikro_usaha mikro_usaha_laku usaha
# 8      7    100  7_infrastruktur_reformasi_bangun infrastruktur...
# 9      8     90                8_digital_era_internet_digitalisasi
#
#                                          CustomName  \
# 0                                           Outlier
# 1                       program & gratis & internet
# 2                             Dukungan Partai PDI-P
# 3                kayak & pasang calon 03 & calon 03
# 4                            kerja & produk & tugas
# 5                             porno & video & viral
# 6                    strategi & strategis & terobos
# 7                       mikro & usaha mikro & usaha
# 8  infrastruktur & reformasi & bangun infrastruktur
# 9                          digital & era & internet
#
#                                       Representation  \
# 0  [warga, pimpin, dukung 03, sambut, anies, hati...
# 1  [program, gratis, internet, koruptor, anak, po...
# 2  [pilih presiden, calon presiden, partai, polit...
# 3  [kayak, pasang calon 03, calon 03, pasang calo...
# 4  [kerja, produk, tugas, produk lokal, kerja nya...
# 5  [porno, video, viral, tonton, film, tonton fil...
# 6  [strategi, strategis, terobos, proyek, posisi,...
# 7  [mikro, usaha mikro, usaha, laku usaha, lokal,...
# 8  [infrastruktur, reformasi, bangun infrastruktu...
# 9  [digital, era, internet, digitalisasi, gratis,...
#
#                                  Representative_Docs
# 0  [bicara orang gerindra tuju antisipasi curang ...
# 1  [masyarakat ganjar mahfud ubah positif reforma...
# 2  [percaya pasang calon presiden calon wakil pre...
# 3  [tonton video video pasang calon 03 kena seran...
# 4  [ragu kerja nyata ganjar mahfud menang, inform...
# 5  [blunder nyata tonton video porno sebab ganjar...
# 6  [langkah ganjar proyek bangun integral visi st...
# 7  [usaha mikro tengah disupport ganjar, ganjar s...
# 8  [gpmmd4 samarinda wadah pikir kreatif generasi...
# 9  [ajar mudah program internet gratis ganjar era...
#
# Campaign Themes for Ganjar-Mahfud:
# Theme: 0_program_gratis_internet_koruptor
# Keywords: program, gratis, internet, koruptor, anak, positif, prof, sejahtera
# Document count: 13092
# --------------------------------------------------
# Theme: 1_pilih presiden_calon presiden_partai_politik
# Keywords: pilih presiden, calon presiden, partai, politik, wakil presiden, calon wakil, calon wakil presiden, wakil
# Document count: 4440
# --------------------------------------------------
# Theme: 2_kayak_pasang calon 03_calon 03_pasang calon
# Keywords: kayak, pasang calon 03, calon 03, pasang calon, 03 menang, dukung 03, pilih 03, suara
# Document count: 3409
# --------------------------------------------------
# Theme: 3_kerja_produk_tugas_produk lokal
# Keywords: kerja, produk, tugas, produk lokal, kerja nyata, lapang kerja, kerja keras, lokal
# Document count: 451
# --------------------------------------------------
# Theme: 4_porno_video_viral_tonton
# Keywords: porno, video, viral, tonton, film, tonton film, hobi, den
# Document count: 190
# --------------------------------------------------
# Theme: 5_strategi_strategis_terobos_proyek
# Keywords: strategi, strategis, terobos, proyek, posisi, langkah, tingkat daya, nasional
# Document count: 146
# --------------------------------------------------
# Theme: 6_mikro_usaha mikro_usaha_laku usaha
# Keywords: mikro, usaha mikro, usaha, laku usaha, lokal, kuliner, produk, promosi
# Document count: 119
# --------------------------------------------------
# Theme: 7_infrastruktur_reformasi_bangun infrastruktur_integrasi
# Keywords: infrastruktur, reformasi, bangun infrastruktur, integrasi, modern, teknologi, lembaga, tumbuh ekonomi
# Document count: 100
# --------------------------------------------------
# Theme: 8_digital_era_internet_digitalisasi
# Keywords: digital, era, internet, digitalisasi, gratis, teknologi, dunia, cepat
# Document count: 90
# --------------------------------------------------
# Theme: 9_tanda duduk_kartu tanda duduk_kartu tanda_kartu
# Keywords: tanda duduk, kartu tanda duduk, kartu tanda, kartu, duduk, tanda, libat, korupsi
# Document count: 79
# --------------------------------------------------
# Theme: 10_jalan_03 03_kucing_siar
# Keywords: jalan, 03 03, kucing, siar, watak, ulang, kutip, gusti
# Document count: 33
# --------------------------------------------------
# Theme: 11_all in_all_in_hikmah
# Keywords: all in, all, in, hikmah, juragan, 01, mahpud, mbak angkie
# Document count: 26
# --------------------------------------------------
# Theme: 12_bts_record_of_has
# Keywords: bts, record, of, has, tidur, the, ibadah, bawa asa
# Document count: 11
# --------------------------------------------------
# Theme: 13_quick_quick count_count_sikap
# Keywords: quick, quick count, count, sikap, cermin sikap, hormat menang, tenang, metode
# Document count: 11
# --------------------------------------------------

# %%
from wordcloud import WordCloud
import seaborn as sns

# %%
# Create topic distribution from the existing topic_info
topic_distribution = topic_info.set_index("Topic")["Count"]

# Get representative documents for key campaign themes
print("\nRepresentative tweets for topic themes themes:")
key_topics = [t for t in topic_distribution.index if t != -1][:5]

for topic_id in key_topics:
    theme_name = topic_model.get_topic_info().loc[topic_model.get_topic_info()["Topic"] == topic_id, "Name"].values[0]
    print(f"\n--- Theme: {theme_name} ---")
    rep_docs = topic_model.get_representative_docs(topic_id)
    for i, doc in enumerate(rep_docs[:3]):
        print(f"{i+1}. {doc[:200]}...")
# Out:
# Representative tweets for topic themes themes:
#
# --- Theme: 0_program_gratis_internet_koruptor ---
# 1. masyarakat ganjar mahfud ubah positif reformasi lembaga baik sistem kelola anggar hebat sat set...
# 2. fokus lindung investor ganjar mahfud bangun fondasi kokoh tumbuh ekonomi inklusif top sat set...
# 3. masyarakat optimis komitmen ganjar mahfud cipta bijak dukung tumbuh ekonomi lanjut juara sat set...
#
# --- Theme: 1_pilih presiden_calon presiden_partai_politik ---
# 1. percaya pasang calon presiden calon wakil presiden ganjar mahfud...
# 2. pilih calon presiden calon wakil presiden sepert ganjar pranowo mahfud md bilang berani dtang acara debat...
# 3. bantu cari manfaat komoditas politik pilih presiden zaman mega presiden partai demokrasi indonesia juang kuasa zaman mahfud prabowo jokowi calon wakil presiden partai demokrasi indonesia juang phpin k...
#
# --- Theme: 2_kayak_pasang calon 03_calon 03_pasang calon ---
# 1. tonton video video pasang calon 03 kena serang bagus film objektif...
# 2. oh laku dukung pasang calon 03 kayak teman tinggal daerah canggu rumah toko...
# 3. nyanyi ayo tunjuk semangat dukung mungut suara coblos pasang calon 03 sejahtera kali lipat indonesia hebat...
#
# --- Theme: 3_kerja_produk_tugas_produk lokal ---
# 1. ragu kerja nyata ganjar mahfud menang...
# 2. informasi gibran tarik mari perhati kerja nyata ganjar mahfud jalan tugas...
# 3. beliau contoh nyata pimpin rakyat rakyat rakyat bukti kerja keras ganjar...
#
# --- Theme: 4_porno_video_viral_tonton ---
# 1. blunder nyata tonton video porno sebab ganjar tinggal prabowo...
# 2. megawaty desak ganjar maaf publik tonton video porno...
# 3. saking bahan ganjar isu basi bahas wadas pildun porno porno laki tonton film porno bohong onani tonton semi full tonton...
