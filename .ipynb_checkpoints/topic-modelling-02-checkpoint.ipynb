# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from bertopic import BERTopic
from bertopic.vectorizers import ClassTfidfTransformer
from bertopic.dimensionality import BaseDimensionalityReduction
from sklearn.feature_extraction.text import CountVectorizer
from cuml.manifold import UMAP
from cuml.cluster import HDBSCAN
from sentence_transformers import SentenceTransformer

# %%
df_02 = pd.read_csv('data/stemmed_merged_kubu_02.csv')

# %%
# Enhanced stopwords list for presidential election dataset
indo_stopwords = [
    # Basic Indonesian stopwords (keep these)
    "yang", "dan", "di", "dengan", "untuk", "dari", "ke", "pada", "ini", "itu",
    "atau", "ada", "juga", "dalam", "saya", "kamu", "anda", "mereka", "kita", "kami",
    "dia", "nya", "adalah", "akan", "oleh", "seperti", "telah", "sudah", "bisa", "dapat",
    "tidak", "tak", "jangan", "ya", "via", "yg", "dgn", "utk", "dr", "pd", "dlm", "sdh", "tdk",
    
    # Common tweet/social media terms
    "via", "rt", "dm", "pm", "cc", "wkwk", "haha", "woi", "hey", "ah", "eh", "oh", "hmm",
    "uwu", "btw", "omg", "lol", "min", "admin", "hehe", "wkwkwk", "awokawok", "hahaha",

        # Locations 
    "indonesia", "jakarta", "jawa", "barat", "timur", "tengah", "sumatra", "bali", "aceh", "selatan", 
    "utara", "kota", "desa", "daerah", "wilayah", "provinsi", "kabupaten", "negara", "republik",

    "mas", "pak", "bu", "bapak", "ibu", "om", "tante", "mbak", "bro", "sis", "bang", "abang",
    "saudara", "laki", "wanita", "kak", "adek", "adik", "kakak", "anak", "bung",

    #candidate names
    "prabowo", "jokowi", "gibran", "subianto", "rakabuming", "anies", "ganjar",
    
]

# %%
vectorizer = CountVectorizer(
    stop_words=indo_stopwords,
    ngram_range=(1, 3),  # Keep bigrams and trigrams for political phrases
    min_df=5,            # Lower threshold to capture more specific topics
    max_df=0.7           # Stricter upper bound to remove very common terms
)

# Configure UMAP for better clustering of political content
umap_model = UMAP(
    n_neighbors=15,      # Smaller neighborhood for more specific clusters
    n_components=5,      
    min_dist=0.0,        # Adjusted for better separation
    metric='cosine',
    random_state=42
)

# More sensitive clustering for political topics
hdbscan_model = HDBSCAN(
    min_cluster_size=10,  # Smaller clusters to capture specific campaign themes
    min_samples=5,       # More lenient sample requirement
    metric='euclidean',
    cluster_selection_method='eom',
    prediction_data=True
)

# Improved c-TF-IDF weighting
ctfidf_model = ClassTfidfTransformer(
    reduce_frequent_words=True,
    bm25_weighting=True
)

embedding_model = SentenceTransformer(
    'distiluse-base-multilingual-cased-v1'
)

# Configure BERTopic for Indonesian political content
topic_model = BERTopic(
    language="multilingual",  # Keep multilingual for Indonesian
    calculate_probabilities=True,
    verbose=True,
    nr_topics=15,             # Reduced from 15 to get more focused topics
    min_topic_size=5,         # Smaller topics to capture campaign themes
    umap_model=umap_model,
    hdbscan_model=hdbscan_model,
    ctfidf_model=ctfidf_model,
    vectorizer_model=vectorizer,
    embedding_model=embedding_model,
)


# Fit the model
topics, probs = topic_model.fit_transform(df_02['full_text'].tolist())
# Out:
# [2025-06-01 18:38:07.168] [CUML] [info] build_algo set to brute_force_knn because random_state is given
# 2025-06-01 18:38:11,233 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches:   0%|          | 0/2951 [00:00<?, ?it/s]
# 2025-06-01 18:38:30,731 - BERTopic - Embedding - Completed ✓
# 2025-06-01 18:38:30,732 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2025-06-01 18:38:32,470 - BERTopic - Dimensionality - Completed ✓
# 2025-06-01 18:38:32,472 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2025-06-01 18:38:35,286 - BERTopic - Cluster - Completed ✓
# 2025-06-01 18:38:35,286 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 2025-06-01 18:38:36,486 - BERTopic - Representation - Completed ✓
# 2025-06-01 18:38:36,486 - BERTopic - Topic reduction - Reducing number of topics
# 2025-06-01 18:38:37,579 - BERTopic - Topic reduction - Reduced number of topics from 404 to 15

# %%
# Define custom topic labels
topic_labels = {}
for topic_id in topic_model.get_topic_info()["Topic"]:
    if topic_id == -1:
        topic_labels[topic_id] = "Outlier"
        continue
        
    # Get top words for the topic
    words = [word for word, _ in topic_model.get_topic(topic_id)[:5]]
    
    # Map topics to specific campaign themes
    if any(term in words for term in ["palestina", "doa", "israel", "gaza"]):
        topic_labels[topic_id] = "Kampanye & Isu Palestina"
    elif any(term in words for term in ["aceh", "warga", "sambut", "bandara", "kedatagan"]):
        topic_labels[topic_id] = "Kunjungan Kampanye Aceh"
    elif any(term in words for term in ["sumbar", "sumatra", "safari", "bukittinggi"]):
        topic_labels[topic_id] = "Kampanye Sumatra Barat"
    elif any(term in words for term in ["adil", "makmur", "sejahtera", "ekonomi"]):
        topic_labels[topic_id] = "Visi Ekonomi & Kemakmuran"
    elif any(term in words for term in ["amin", "bismillah", "islam", "muslim"]):
        topic_labels[topic_id] = "Dukungan Religius"
    elif any(term in words for term in ["pesantren", "santri", "kiai", "ulama"]):
        topic_labels[topic_id] = "Dukungan Pesantren"
    elif any(term in words for term in ["konstitusi", "mk", "etik", "putus"]):
        topic_labels[topic_id] = "Polemik Mahkamah Konstitusi"
    elif any(term in words for term in ["solo", "surakarta", "wali"]):
        topic_labels[topic_id] = "Kinerja di Solo"
    elif any(term in words for term in ["elektabilitas", "unggul", "menang", "putar"]):
        topic_labels[topic_id] = "Elektabilitas & Polling"
    elif any(term in words for term in ["joget", "pidato", "debat", "acara"]):
        topic_labels[topic_id] = "Penampilan Pidato & Debat"
    else:
        # Use top 3 words as label for other topics
        topic_labels[topic_id] = " & ".join(words[:3])

# Apply custom labels
topic_model.set_topic_labels(topic_labels)

# %%
from wordcloud import WordCloud

# %%
# Get the improved topic information
topic_info = topic_model.get_topic_info()
print("\nImproved Topic Information:")
print(topic_info.head(10))

# Print topics with their new labels
print("\nTopik Pembicaraan Masyarakat terhadap Pasangan Prabowo-Gibran:")
for index, row in topic_info.iterrows():
    if row["Topic"] != -1:  # Skip outlier topic
        topic_id = row["Topic"]
        words = [word[0] for word in topic_model.get_topic(topic_id)[:8]]
        print(f"Theme: {row['Name']}")
        print(f"Keywords: {', '.join(words)}")
        print(f"Document count: {row['Count']}")
        print("-" * 50)

# Create a topic distribution visualization
plt.figure(figsize=(12, 6))
topic_counts = topic_info[topic_info["Topic"] != -1]["Count"]
topic_names = [label for topic, label in topic_labels.items() if topic != -1][:len(topic_counts)]

# Plot with better color scheme
bars = plt.bar(topic_names, topic_counts, color=plt.cm.viridis(np.linspace(0, 1, len(topic_counts))))

# Add count labels on top of bars
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height + 0.5,
            f'{int(height)}', ha='center', va='bottom', fontweight='bold')

plt.xticks(rotation=45, ha="right")
plt.title("Distribusi Topik Pembicaraan Masyarakat Terhadap Pasangan Prabowo-Gibran", fontsize=14, fontweight='bold')
plt.xlabel("Topik Pembicaraan", fontsize=12)
plt.ylabel("Number of Tweets", fontsize=12)
plt.tight_layout()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# Display interactive visualizations
intertopic_map = topic_model.visualize_topics()
display(intertopic_map)

# Create hierarchical clustering visualization
hierarchy = topic_model.visualize_hierarchy()
display(hierarchy)

# Create heatmap of topic similarities
heatmap = topic_model.visualize_heatmap()
display(heatmap)

# Create word clouds for top 3 topics
plt.figure(figsize=(15, 10))
for i, topic_id in enumerate(topic_info[topic_info['Topic'] != -1]['Topic'][:3]):
    plt.subplot(1, 3, i+1)
    
    # Get topic words and weights
    words = dict(topic_model.get_topic(topic_id)[:15])
    
    # Create and display wordcloud
    wordcloud = WordCloud(width=400, height=400, background_color='white', 
                          colormap='viridis', max_words=50).generate_from_frequencies(words)
    
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.title(f"Topic: {topic_labels[topic_id]}", fontsize=12)
    plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# Improved Topic Information:
#    Topic  Count                                            Name  \
# 0     -1  38844                     -1_sih_dukung 02_deh_buzzer
# 1      0  34365          0_debat_presiden 02_dukung 02_calon 02
# 2      1   9181                 1_estate_food estate_food_kerja
# 3      2   7353            2_politik_raka_pilih presiden_polisi
# 4      3   2592        3_demokrasi_partai demokrasi_suara_juang
# 5      4   1252                  4_video_film_viral_lihat video
# 6      5    319               5_strategi_strategis_proyek_pakai
# 7      6    165  6_ekonomi_tumbuh ekonomi_tumbuh_ekonomi rakyat
# 8      7    117                      7_edit_reformasi_orde_cape
# 9      8     85                8_energi_hijau_positif_inspirasi
#
#                              CustomName  \
# 0                               Outlier
# 1             Penampilan Pidato & Debat
# 2               Elektabilitas & Polling
# 3       politik & raka & pilih presiden
# 4  demokrasi & partai demokrasi & suara
# 5                  video & film & viral
# 6         strategi & strategis & proyek
# 7             Visi Ekonomi & Kemakmuran
# 8               edit & reformasi & orde
# 9              energi & hijau & positif
#
#                                       Representation  \
# 0  [sih, dukung 02, deh, buzzer, salah, bilang, t...
# 1  [debat, presiden 02, dukung 02, calon 02, pasa...
# 2  [estate, food estate, food, kerja, menang, gem...
# 3  [politik, raka, pilih presiden, polisi, wakil ...
# 4  [demokrasi, partai demokrasi, suara, juang, de...
# 5  [video, film, viral, lihat video, televisi, di...
# 6  [strategi, strategis, proyek, pakai, anggar, c...
# 7  [ekonomi, tumbuh ekonomi, tumbuh, ekonomi raky...
# 8  [edit, reformasi, orde, cape, juang reformasi,...
# 9  [energi, hijau, positif, inspirasi, semangat, ...
#
#                                  Representative_Docs
# 0  [simpul mkmk rekomendasi sanksi pecat ketua mk...
# 1  [badan awas pilih gerak telusur dukung aparatu...
# 2  [prabowo pintar kerja nyata rasa kerja contoh ...
# 3  [pasang calon presiden calon presiden calon wa...
# 4  [contoh partai adil sejahtera seringkali tenta...
# 5  [sibuk maki maki ketar tir bilang panik tkn 02...
# 6  [rahasia cokk buzzer 02 anggar strategi perang...
# 7  [prabowo keren visi pakprabowo masgibran naik ...
# 8  [prabowo parahni edit, edit 02 kur, najis pili...
# 9  [gibran visi energi hijau bikin indonesia, gib...
#
# Topik Pembicaraan Masyarakat terhadap Pasangan Prabowo-Gibran:
# Theme: 0_debat_presiden 02_dukung 02_calon 02
# Keywords: debat, presiden 02, dukung 02, calon 02, pasang calon 02, kayak, calon presiden, pilih 02
# Document count: 34365
# --------------------------------------------------
# Theme: 1_estate_food estate_food_kerja
# Keywords: estate, food estate, food, kerja, menang, gemoy, mundur, asam
# Document count: 9181
# --------------------------------------------------
# Theme: 2_politik_raka_pilih presiden_polisi
# Keywords: politik, raka, pilih presiden, polisi, wakil presiden, program, wakil, calon wakil presiden
# Document count: 7353
# --------------------------------------------------
# Theme: 3_demokrasi_partai demokrasi_suara_juang
# Keywords: demokrasi, partai demokrasi, suara, juang, demokrat, partai, mungut, mungut suara
# Document count: 2592
# --------------------------------------------------
# Theme: 4_video_film_viral_lihat video
# Keywords: video, film, viral, lihat video, televisi, dirty, dirty pilih, viralkan
# Document count: 1252
# --------------------------------------------------
# Theme: 5_strategi_strategis_proyek_pakai
# Keywords: strategi, strategis, proyek, pakai, anggar, cari simpati, debat, rahasia
# Document count: 319
# --------------------------------------------------
# Theme: 6_ekonomi_tumbuh ekonomi_tumbuh_ekonomi rakyat
# Keywords: ekonomi, tumbuh ekonomi, tumbuh, ekonomi rakyat, cipta, bangun, lanjutgan, lapang kerja
# Document count: 165
# --------------------------------------------------
# Theme: 7_edit_reformasi_orde_cape
# Keywords: edit, reformasi, orde, cape, juang reformasi, cape cape, gagal reformasi, 02 rugi
# Document count: 117
# --------------------------------------------------
# Theme: 8_energi_hijau_positif_inspirasi
# Keywords: energi, hijau, positif, inspirasi, semangat, ide, optimis, raja
# Document count: 85
# --------------------------------------------------
# Theme: 9_direct message_message_direct_online
# Keywords: direct message, message, direct, online, ojek online, ojek, id, cah
# Document count: 37
# --------------------------------------------------
# Theme: 10_solo_sibuk kampanye_kerja_inspiratif
# Keywords: solo, sibuk kampanye, kerja, inspiratif, dedikasi, fokus kerja, contoh, respek
# Document count: 33
# --------------------------------------------------
# Theme: 11_teori_konspirasi_praktik_handal
# Keywords: teori, konspirasi, praktik, handal, korea pop, pop, khayal, respek
# Document count: 26
# --------------------------------------------------
# Theme: 12_sungai_abdul_wangi_jorok
# Keywords: sungai, abdul, wangi, jorok, sultan, tan, sri, kucing
# Document count: 24
# --------------------------------------------------
# Theme: 13_kreatif_teknologi_inspirasi_sentuh
# Keywords: kreatif, teknologi, inspirasi, sentuh, terobos, bas, kaleng, tarik
# Document count: 17
# --------------------------------------------------

# %%
from wordcloud import WordCloud
import seaborn as sns

# %%
# Create topic distribution from the existing topic_info
topic_distribution = topic_info.set_index("Topic")["Count"]

# Get representative documents for key campaign themes
print("\nRepresentative tweets for key topic:")
key_topics = [t for t in topic_distribution.index if t != -1][:5]

for topic_id in key_topics:
    theme_name = topic_model.get_topic_info().loc[topic_model.get_topic_info()["Topic"] == topic_id, "Name"].values[0]
    print(f"\n--- Theme: {theme_name} ---")
    rep_docs = topic_model.get_representative_docs(topic_id)
    for i, doc in enumerate(rep_docs[:3]):
        print(f"{i+1}. {doc[:200]}...")
# Out:
# Representative tweets for key topic:
#
# --- Theme: 0_debat_presiden 02_dukung 02_calon 02 ---
# 1. badan awas pilih gerak telusur dukung aparatur perintah desa calon presiden calon wakil presiden nomor 02 prabowo subianto gibran rakabuming...
# 2. coba calon presiden calon wakil presiden 02 suruh sholawatan...
# 3. prabowo debat calon wakil presiden komisi pemelihan main pilih presiden...
#
# --- Theme: 1_estate_food estate_food_kerja ---
# 1. prabowo pintar kerja nyata rasa kerja contoh kalimat orang mimpi halusinasi lawak sebut kerja prabowo rasa kerja pesawat bekas food estate gagal...
# 2. prabowo beli pesawat bekas tutup kurang alat utama sistem tahan sebab banyak alat utama sistem tahan usang pensiun prabowo mes pesawat rafale prancis f15 mantan amerika langsung mesti tunggu tahun...
# 3. prabowo paket lengkap culik tukang marah khianat ulama dukung penjara diri masuk istana langgar konstitusi koruptor alat utama sistem tahan usak lingkung food estate istri gagal urus rumah tangga anak...
#
# --- Theme: 2_politik_raka_pilih presiden_polisi ---
# 1. pasang calon presiden calon presiden calon wakil presiden calon wakil presiden prabowo subianto gibran rakabuming raka janji atas sanitasi air bersih infrastuktur indonesia...
# 2. komisi pemelihan ri terima daftar pasang calon presiden calon wakil presiden iskandar ganjar pranowo mahfud md subianto rakabuming raka ganjar mahfud hebat prabowo gibran...
# 3. elektabilitas calon presiden calon wakil presiden nomor urut prabowo subianto gibran rakabuming raka unggul prabowo subianto...
#
# --- Theme: 3_demokrasi_partai demokrasi_suara_juang ---
# 1. contoh partai adil sejahtera seringkali tentang suara dewan wakil rakyat ri partai demokrasi indonesia juang demo bahan bakar minyak susilo bambang yudhoyono gue deny prabowo masuk menteri jokowi ya u...
# 2. partai demokrasi indonesia juang usil 02 ganjar njeblok...
# 3. bahaya suka elit2 partai demokrasi indonesia juang gembosin suara 02 wkwk...
#
# --- Theme: 4_video_film_viral_lihat video ---
# 1. sibuk maki maki ketar tir bilang panik tkn 02 langsung tuding film fitnah potongan2 video narasi aneh platform tekan orang film film fitnah...
# 2. zarry tonton video sih nyata prof yusril amin kata tkn 02 film fitnah film kuat duduk film...
# 3. coba teman dukung 02 dirty pilih kampanye hitam apa rilis pas tenang ngerilis paslonnya kasih video tiktok bahas film dirty pilih substansi film...
