# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from bertopic import BERTopic
from bertopic.vectorizers import ClassTfidfTransformer
from bertopic.dimensionality import BaseDimensionalityReduction
from sklearn.feature_extraction.text import CountVectorizer
from cuml.manifold import UMAP
from cuml.cluster import HDBSCAN
from sentence_transformers import SentenceTransformer

# %%
df_02 = pd.read_csv('data/stemmed_merged_kubu_02.csv')

# %%
# Enhanced stopwords list for presidential election dataset
indo_stopwords = [
    # Basic Indonesian stopwords (keep these)
    "yang", "dan", "di", "dengan", "untuk", "dari", "ke", "pada", "ini", "itu",
    "atau", "ada", "juga", "dalam", "saya", "kamu", "anda", "mereka", "kita", "kami",
    "dia", "nya", "adalah", "akan", "oleh", "seperti", "telah", "sudah", "bisa", "dapat",
    "tidak", "tak", "jangan", "ya", "via", "yg", "dgn", "utk", "dr", "pd", "dlm", "sdh", "tdk",
    
    # Common tweet/social media terms
    "via", "rt", "dm", "pm", "cc", "wkwk", "haha", "woi", "hey", "ah", "eh", "oh", "hmm",
    "uwu", "btw", "omg", "lol", "min", "admin", "hehe", "wkwkwk", "awokawok", "hahaha",

        # Locations 
    "indonesia", "jakarta", "jawa", "barat", "timur", "tengah", "sumatra", "bali", "aceh", "selatan", 
    "utara", "kota", "desa", "daerah", "wilayah", "provinsi", "kabupaten", "negara", "republik",

    "mas", "pak", "bu", "bapak", "ibu", "om", "tante", "mbak", "bro", "sis", "bang", "abang",
    "saudara", "laki", "wanita", "kak", "adek", "adik", "kakak", "anak", "bung",

    #candidate names
    "prabowo", "jokowi", "gibran", "subianto", "rakabuming", "anies", "ganjar",
    
]

# %%
vectorizer = CountVectorizer(
    stop_words=indo_stopwords,
    ngram_range=(1, 3),  # Keep bigrams and trigrams for political phrases
    min_df=5,            # Lower threshold to capture more specific topics
    max_df=0.7           # Stricter upper bound to remove very common terms
)

# Configure UMAP for better clustering of political content
umap_model = UMAP(
    n_neighbors=15,      # Smaller neighborhood for more specific clusters
    n_components=5,      
    min_dist=0.0,        # Adjusted for better separation
    metric='cosine',
    random_state=42
)

# More sensitive clustering for political topics
hdbscan_model = HDBSCAN(
    min_cluster_size=10,  # Smaller clusters to capture specific campaign themes
    min_samples=5,       # More lenient sample requirement
    metric='euclidean',
    cluster_selection_method='eom',
    prediction_data=True
)

# Improved c-TF-IDF weighting
ctfidf_model = ClassTfidfTransformer(
    reduce_frequent_words=True,
    bm25_weighting=True
)

embedding_model = SentenceTransformer(
    'distiluse-base-multilingual-cased-v1'
)

# Configure BERTopic for Indonesian political content
topic_model = BERTopic(
    language="multilingual",  # Keep multilingual for Indonesian
    calculate_probabilities=True,
    verbose=True,
    nr_topics=15,             # Reduced from 15 to get more focused topics
    min_topic_size=5,         # Smaller topics to capture campaign themes
    umap_model=umap_model,
    hdbscan_model=hdbscan_model,
    ctfidf_model=ctfidf_model,
    vectorizer_model=vectorizer,
    embedding_model=embedding_model,
)


# Fit the model
topics, probs = topic_model.fit_transform(df_02['full_text'].tolist())
# Out:
# [2025-06-02 15:11:45.842] [CUML] [info] build_algo set to brute_force_knn because random_state is given
# 2025-06-02 15:11:50,085 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches:   0%|          | 0/2951 [00:00<?, ?it/s]
# 2025-06-02 15:12:09,452 - BERTopic - Embedding - Completed ✓
# 2025-06-02 15:12:09,453 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2025-06-02 15:12:11,115 - BERTopic - Dimensionality - Completed ✓
# 2025-06-02 15:12:11,118 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2025-06-02 15:12:13,777 - BERTopic - Cluster - Completed ✓
# 2025-06-02 15:12:13,778 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 2025-06-02 15:12:14,986 - BERTopic - Representation - Completed ✓
# 2025-06-02 15:12:14,987 - BERTopic - Topic reduction - Reducing number of topics
# 2025-06-02 15:12:16,081 - BERTopic - Topic reduction - Reduced number of topics from 389 to 15

# %%
# Define custom topic labels
topic_labels = {}
for topic_id in topic_model.get_topic_info()["Topic"]:
    if topic_id == -1:
        topic_labels[topic_id] = "Outlier"
        continue
        
    # Get top words for the topic
    words = [word for word, _ in topic_model.get_topic(topic_id)[:5]]
    
    # Map topics to specific campaign themes
    if any(term in words for term in ["palestina", "doa", "israel", "gaza"]):
        topic_labels[topic_id] = "Kampanye & Isu Palestina"
    elif any(term in words for term in ["aceh", "warga", "sambut", "bandara", "kedatagan"]):
        topic_labels[topic_id] = "Kunjungan Kampanye Aceh"
    elif any(term in words for term in ["sumbar", "sumatra", "safari", "bukittinggi"]):
        topic_labels[topic_id] = "Kampanye Sumatra Barat"
    elif any(term in words for term in ["adil", "makmur", "sejahtera", "ekonomi"]):
        topic_labels[topic_id] = "Visi Ekonomi & Kemakmuran"
    elif any(term in words for term in ["amin", "bismillah", "islam", "muslim"]):
        topic_labels[topic_id] = "Dukungan Religius"
    elif any(term in words for term in ["pesantren", "santri", "kiai", "ulama"]):
        topic_labels[topic_id] = "Dukungan Pesantren"
    elif any(term in words for term in ["konstitusi", "mk", "etik", "putus"]):
        topic_labels[topic_id] = "Polemik Mahkamah Konstitusi"
    elif any(term in words for term in ["solo", "surakarta", "wali"]):
        topic_labels[topic_id] = "Kinerja di Solo"
    elif any(term in words for term in ["elektabilitas", "unggul", "menang", "putar"]):
        topic_labels[topic_id] = "Elektabilitas & Polling"
    elif any(term in words for term in ["joget", "pidato", "debat", "acara"]):
        topic_labels[topic_id] = "Penampilan Pidato & Debat"
    else:
        # Use top 3 words as label for other topics
        topic_labels[topic_id] = " & ".join(words[:3])

# Apply custom labels
topic_model.set_topic_labels(topic_labels)

# %%
from wordcloud import WordCloud

# %%
# Get the improved topic information
topic_info = topic_model.get_topic_info()
print("\nImproved Topic Information:")
print(topic_info.head(10))

# Print topics with their new labels
print("\nTopik Pembicaraan Masyarakat terhadap Pasangan Prabowo-Gibran:")
for index, row in topic_info.iterrows():
    if row["Topic"] != -1:  # Skip outlier topic
        topic_id = row["Topic"]
        words = [word[0] for word in topic_model.get_topic(topic_id)[:8]]
        print(f"Theme: {row['Name']}")
        print(f"Keywords: {', '.join(words)}")
        print(f"Document count: {row['Count']}")
        print("-" * 50)

# Create a topic distribution visualization
plt.figure(figsize=(12, 6))
topic_counts = topic_info[topic_info["Topic"] != -1]["Count"]
topic_names = [label for topic, label in topic_labels.items() if topic != -1][:len(topic_counts)]

# Plot with better color scheme
bars = plt.bar(topic_names, topic_counts, color=plt.cm.viridis(np.linspace(0, 1, len(topic_counts))))

# Add count labels on top of bars
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height + 0.5,
            f'{int(height)}', ha='center', va='bottom', fontweight='bold')

plt.xticks(rotation=45, ha="right")
plt.title("Distribusi Topik Pembicaraan Masyarakat Terhadap Pasangan Prabowo-Gibran", fontsize=14, fontweight='bold')
plt.xlabel("Topik Pembicaraan", fontsize=12)
plt.ylabel("Number of Tweets", fontsize=12)
plt.tight_layout()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# Display interactive visualizations
intertopic_map = topic_model.visualize_topics()
display(intertopic_map)

# Create hierarchical clustering visualization
hierarchy = topic_model.visualize_hierarchy()
display(hierarchy)

# Create heatmap of topic similarities
heatmap = topic_model.visualize_heatmap()
display(heatmap)

# Create word clouds for top 3 topics
plt.figure(figsize=(15, 10))
for i, topic_id in enumerate(topic_info[topic_info['Topic'] != -1]['Topic'][:3]):
    plt.subplot(1, 3, i+1)
    
    # Get topic words and weights
    words = dict(topic_model.get_topic(topic_id)[:15])
    
    # Create and display wordcloud
    wordcloud = WordCloud(width=400, height=400, background_color='white', 
                          colormap='viridis', max_words=50).generate_from_frequencies(words)
    
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.title(f"Topic: {topic_labels[topic_id]}", fontsize=12)
    plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# Improved Topic Information:
#    Topic  Count                                               Name  \
# 0     -1  35541                          -1_deh_tim_debat_pilih 02
# 1      0  28721               0_dukung 02_pilih 02_buzzer 02_suara
# 2      1  14701                          1_video_raka_survei_kerja
# 3      2  13661  2_calon presiden_wakil presiden_calon wakil pr...
# 4      3    974                 3_program_gratis_makan siang_siang
# 5      4    171                   4_dokter_mikro_usaha mikro_usaha
# 6      5    170      5_ekonomi_tumbuh_infrastruktur_ekonomi rakyat
# 7      6    122           6_edit_reformasi_02 edit_juang reformasi
# 8      7    108                       7_konsep_idealisme_ide_ideal
# 9      8     71  8_sistem_utama sistem_alat utama sistem_alat u...
#
#                                           CustomName  \
# 0                                            Outlier
# 1                   dukung 02 & pilih 02 & buzzer 02
# 2                              video & raka & survei
# 3  calon presiden & wakil presiden & calon wakil ...
# 4                     program & gratis & makan siang
# 5                       dokter & mikro & usaha mikro
# 6                          Visi Ekonomi & Kemakmuran
# 7                         edit & reformasi & 02 edit
# 8                           konsep & idealisme & ide
# 9          sistem & utama sistem & alat utama sistem
#
#                                       Representation  \
# 0  [deh, tim, debat, pilih 02, dukung 02, hati, p...
# 1  [dukung 02, pilih 02, buzzer 02, suara, 02 men...
# 2  [video, raka, survei, kerja, masyarakat, estat...
# 3  [calon presiden, wakil presiden, calon wakil p...
# 4  [program, gratis, makan siang, siang, makan, s...
# 5  [dokter, mikro, usaha mikro, usaha, dokter tif...
# 6  [ekonomi, tumbuh, infrastruktur, ekonomi rakya...
# 7  [edit, reformasi, 02 edit, juang reformasi, or...
# 8  [konsep, idealisme, ide, ideal, idealis, ide i...
# 9  [sistem, utama sistem, alat utama sistem, alat...
#
#                                  Representative_Docs
# 0  [ukur samsul forum debat trformat singkat subt...
# 1  [keras kepala pilih 02 siikk hati tutup banyak...
# 2  [prabowo agus hebat pamen tentara nasional ind...
# 3  [duet calon presiden calon presiden prabowo su...
# 4  [tilik program makan siang susu gratis prabowo...
# 5  [mati usaha mikro tengah usaha dukung 02, 02 n...
# 6  [prabowo top visi pakprabowo masgibran naik tu...
# 7  [cape cape reformasi keringat darah tumpah mil...
# 8  [cak imin prof mahfud hebat konsep negara hubu...
# 9  [pasang calon 02 beli alat utama sistem tahan ...
#
# Topik Pembicaraan Masyarakat terhadap Pasangan Prabowo-Gibran:
# Theme: 0_dukung 02_pilih 02_buzzer 02_suara
# Keywords: dukung 02, pilih 02, buzzer 02, suara, 02 menang, agama, kubu 02, 02 02
# Document count: 28721
# --------------------------------------------------
# Theme: 1_video_raka_survei_kerja
# Keywords: video, raka, survei, kerja, masyarakat, estate, food, food estate
# Document count: 14701
# --------------------------------------------------
# Theme: 2_calon presiden_wakil presiden_calon wakil presiden_calon wakil
# Keywords: calon presiden, wakil presiden, calon wakil presiden, calon wakil, politik, debat, presiden 02, wakil
# Document count: 13661
# --------------------------------------------------
# Theme: 3_program_gratis_makan siang_siang
# Keywords: program, gratis, makan siang, siang, makan, siang gratis, makan siang gratis, program makan
# Document count: 974
# --------------------------------------------------
# Theme: 4_dokter_mikro_usaha mikro_usaha
# Keywords: dokter, mikro, usaha mikro, usaha, dokter tifa, back, minim, tifa
# Document count: 171
# --------------------------------------------------
# Theme: 5_ekonomi_tumbuh_infrastruktur_ekonomi rakyat
# Keywords: ekonomi, tumbuh, infrastruktur, ekonomi rakyat, cipta, pakprabowo, cipta lapang kerja, cipta lapang
# Document count: 170
# --------------------------------------------------
# Theme: 6_edit_reformasi_02 edit_juang reformasi
# Keywords: edit, reformasi, 02 edit, juang reformasi, orde, cape, cape cape, 02 rugi
# Document count: 122
# --------------------------------------------------
# Theme: 7_konsep_idealisme_ide_ideal
# Keywords: konsep, idealisme, ide, ideal, idealis, ide ide, gagas ide, action
# Document count: 108
# --------------------------------------------------
# Theme: 8_sistem_utama sistem_alat utama sistem_alat utama
# Keywords: sistem, utama sistem, alat utama sistem, alat utama, sistem tahan, utama sistem tahan, alat, utama
# Document count: 71
# --------------------------------------------------
# Theme: 9_car free day_car free_free day_car
# Keywords: car free day, car free, free day, car, free, day, susu car free, susu car
# Document count: 55
# --------------------------------------------------
# Theme: 10_tulis_tuli_buta tuli_buku
# Keywords: tulis, tuli, buta tuli, buku, berkat, tulis gambar, nama pribadi, salah baca
# Document count: 44
# --------------------------------------------------
# Theme: 11_direct message_message_direct_online
# Keywords: direct message, message, direct, online, ojek online, ojek, cah, aki
# Document count: 38
# --------------------------------------------------
# Theme: 12_malu in_sungai_abdul_besi
# Keywords: malu in, sungai, abdul, besi, wangi, 02 norak, sultan, tan
# Document count: 23
# --------------------------------------------------
# Theme: 13_ongkos_gbla_80t_tribun
# Keywords: ongkos, gbla, 80t, tribun, kapasitas, hitung, dosa, oi
# Document count: 10
# --------------------------------------------------

# %%
from wordcloud import WordCloud
import seaborn as sns

# %%
# Create topic distribution from the existing topic_info
topic_distribution = topic_info.set_index("Topic")["Count"]

# Get representative documents for key campaign themes
print("\nRepresentative tweets for key topic:")
key_topics = [t for t in topic_distribution.index if t != -1][:5]

for topic_id in key_topics:
    theme_name = topic_model.get_topic_info().loc[topic_model.get_topic_info()["Topic"] == topic_id, "Name"].values[0]
    print(f"\n--- Theme: {theme_name} ---")
    rep_docs = topic_model.get_representative_docs(topic_id)
    for i, doc in enumerate(rep_docs[:3]):
        print(f"{i+1}. {doc[:200]}...")
# Out:
# Representative tweets for key topic:
#
# --- Theme: 0_dukung 02_pilih 02_buzzer 02_suara ---
# 1. keras kepala pilih 02 siikk hati tutup banyak fakta cari bela karepmuu weess angel angeell...
# 2. syekali ojek online kesusu bikin nyata tumpang tindih jelas komrad2 prabowo ngomong-ngomong maki anis bicara kubu 02 lapor komisi pemelihan mbak...
# 3. acara desak anies isi rakyat bang kampanye anies mana ramai kandang partai adil sejahtera jujur aneh 02 dunia maya hujat media mainstream publik enemy kampanye rakyat jarang sekali kampanye sepi surve...
#
# --- Theme: 1_video_raka_survei_kerja ---
# 1. prabowo agus hebat pamen tentara nasional indonesia ketua partai cak imin ketua partai menteri...
# 2. sikap tkn prabowo gibran batas yakin rawan doa contoh pimpin bijaksana harga bebas agama putus pupuk semangat kerja pandang beda...
# 3. prabowo joget gemoy joget bikin masyarakat lapar gara gara food estate hasil...
#
# --- Theme: 2_calon presiden_wakil presiden_calon wakil presiden_calon wakil ---
# 1. duet calon presiden calon presiden prabowo subianto calon wakil presiden calon wakil presiden gibran rakabuming raka nilai bawa indonesia hadap tantang global prabowo subianto...
# 2. orde deh masalah ulang fase calon presiden calon wakil presiden 02 dua picik twit bodoh baca...
# 3. gojek cerita debat calon presiden calon wakil presiden pandang opini ajak diskusi tetangga kos mahasiswa all in 02 calon wakil presiden keren banget berani maju pilih presiden not salah ganjal pas den...
#
# --- Theme: 3_program_gratis_makan siang_siang ---
# 1. tilik program makan siang susu gratis prabowo gibran siswa...
# 2. kepincut program makan siang susu gratis bsm bayar instusi dukung prabowo gibran gibran...
# 3. buzzer 02 gizi program makan siang gratis cocok...
#
# --- Theme: 4_dokter_mikro_usaha mikro_usaha ---
# 1. mati usaha mikro tengah usaha dukung 02...
# 2. 02 nice pindah to reduce staple food impor indomie inflasi harga sembilan bahan pokok produk ritel pajak usaha mikro tengah demo naik harga minum manis kemas usaha mikro tengah will thrive industri bu...
# 3. calon wakil presiden 02 gibran rakabuming raka awal usaha mikro tengah bantu pamer izin ajak masyarakat cinta produk negeri usaha mikro tengah indonesia kembang maju dukung maju usaha mikro tengah ind...
