# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from bertopic import BERTopic
from bertopic.vectorizers import ClassTfidfTransformer
from bertopic.dimensionality import BaseDimensionalityReduction
from sklearn.feature_extraction.text import CountVectorizer
from cuml.manifold import UMAP
from cuml.cluster import HDBSCAN
from sentence_transformers import SentenceTransformer

# %%
df_02 = pd.read_csv('data/stemmed_merged_kubu_02.csv')

# %%
# Enhanced stopwords list for presidential election dataset
indo_stopwords = [
    # Basic Indonesian stopwords (keep these)
    "yang", "dan", "di", "dengan", "untuk", "dari", "ke", "pada", "ini", "itu",
    "atau", "ada", "juga", "dalam", "saya", "kamu", "anda", "mereka", "kita", "kami",
    "dia", "nya", "adalah", "akan", "oleh", "seperti", "telah", "sudah", "bisa", "dapat",
    "tidak", "tak", "jangan", "ya", "via", "yg", "dgn", "utk", "dr", "pd", "dlm", "sdh", "tdk",
    
    # Common tweet/social media terms
    "via", "rt", "dm", "pm", "cc", "wkwk", "haha", "woi", "hey", "ah", "eh", "oh", "hmm",
    "uwu", "btw", "omg", "lol", "min", "admin", "hehe", "wkwkwk", "awokawok", "hahaha",

        # Locations 
    "indonesia", "jakarta", "jawa", "barat", "timur", "tengah", "sumatra", "bali", "aceh", "selatan", 
    "utara", "kota", "desa", "daerah", "wilayah", "provinsi", "kabupaten", "negara", "republik",

    "mas", "pak", "bu", "bapak", "ibu", "om", "tante", "mbak", "bro", "sis", "bang", "abang",
    "saudara", "laki", "wanita", "kak", "adek", "adik", "kakak", "anak", "bung",

    #candidate names
    "prabowo", "jokowi", "gibran", "subianto", "rakabuming", "anies", "ganjar", "raka", "mikro",
    
]

# %%
vectorizer = CountVectorizer(
    stop_words=indo_stopwords,
    ngram_range=(1, 3),  # Keep bigrams and trigrams for political phrases
    min_df=5,            # Lower threshold to capture more specific topics
    max_df=0.7           # Stricter upper bound to remove very common terms
)

# Configure UMAP for better clustering of political content
umap_model = UMAP(
    n_neighbors=15,      # Smaller neighborhood for more specific clusters
    n_components=5,      
    min_dist=0.0,        # Adjusted for better separation
    metric='cosine',
    random_state=42
)

# More sensitive clustering for political topics
hdbscan_model = HDBSCAN(
    min_cluster_size=10,  # Smaller clusters to capture specific campaign themes
    min_samples=5,       # More lenient sample requirement
    metric='euclidean',
    cluster_selection_method='eom',
    prediction_data=True
)

# Improved c-TF-IDF weighting
ctfidf_model = ClassTfidfTransformer(
    reduce_frequent_words=True,
    bm25_weighting=True
)

embedding_model = SentenceTransformer(
    'distiluse-base-multilingual-cased-v1'
)

# Configure BERTopic for Indonesian political content
topic_model = BERTopic(
    language="multilingual",  # Keep multilingual for Indonesian
    calculate_probabilities=True,
    verbose=True,
    nr_topics=15,             # Reduced from 15 to get more focused topics
    min_topic_size=5,         # Smaller topics to capture campaign themes
    umap_model=umap_model,
    hdbscan_model=hdbscan_model,
    ctfidf_model=ctfidf_model,
    vectorizer_model=vectorizer,
    embedding_model=embedding_model,
)


# Fit the model
topics, probs = topic_model.fit_transform(df_02['full_text'].tolist())
# Out:
# [2025-06-02 16:07:14.140] [CUML] [info] build_algo set to brute_force_knn because random_state is given
# 2025-06-02 16:07:18,094 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches:   0%|          | 0/2951 [00:00<?, ?it/s]
# 2025-06-02 16:07:39,370 - BERTopic - Embedding - Completed ✓
# 2025-06-02 16:07:39,371 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2025-06-02 16:07:41,034 - BERTopic - Dimensionality - Completed ✓
# 2025-06-02 16:07:41,037 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2025-06-02 16:07:44,181 - BERTopic - Cluster - Completed ✓
# 2025-06-02 16:07:44,181 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 2025-06-02 16:07:45,428 - BERTopic - Representation - Completed ✓
# 2025-06-02 16:07:45,428 - BERTopic - Topic reduction - Reducing number of topics
# 2025-06-02 16:07:46,556 - BERTopic - Topic reduction - Reduced number of topics from 387 to 15

# %%
# Define custom topic labels
topic_labels = {}
for topic_id in topic_model.get_topic_info()["Topic"]:
    if topic_id == -1:
        topic_labels[topic_id] = "Outlier"
        continue
        
    # Get top words for the topic
    words = [word for word, _ in topic_model.get_topic(topic_id)[:5]]
    
    # Map topics to specific campaign themes
    if any(term in words for term in ["palestina", "doa", "israel", "gaza"]):
        topic_labels[topic_id] = "Kampanye & Isu Palestina"
    elif any(term in words for term in ["aceh", "warga", "sambut", "bandara", "kedatagan"]):
        topic_labels[topic_id] = "Kunjungan Kampanye Aceh"
    elif any(term in words for term in ["sumbar", "sumatra", "safari", "bukittinggi"]):
        topic_labels[topic_id] = "Kampanye Sumatra Barat"
    elif any(term in words for term in ["adil", "makmur", "sejahtera", "ekonomi"]):
        topic_labels[topic_id] = "Visi Ekonomi & Kemakmuran"
    elif any(term in words for term in ["amin", "bismillah", "islam", "muslim"]):
        topic_labels[topic_id] = "Dukungan Religius"
    elif any(term in words for term in ["pesantren", "santri", "kiai", "ulama"]):
        topic_labels[topic_id] = "Dukungan Pesantren"
    elif any(term in words for term in ["konstitusi", "mk", "etik", "putus"]):
        topic_labels[topic_id] = "Polemik Mahkamah Konstitusi"
    elif any(term in words for term in ["solo", "surakarta", "wali"]):
        topic_labels[topic_id] = "Kinerja di Solo"
    elif any(term in words for term in ["elektabilitas", "unggul", "menang", "putar"]):
        topic_labels[topic_id] = "Elektabilitas & Polling"
    elif any(term in words for term in ["joget", "pidato", "debat", "acara"]):
        topic_labels[topic_id] = "Penampilan Pidato & Debat"
    else:
        # Use top 3 words as label for other topics
        topic_labels[topic_id] = " & ".join(words[:3])

# Apply custom labels
topic_model.set_topic_labels(topic_labels)

# %%
from wordcloud import WordCloud

# %%
# Get the improved topic information
topic_info = topic_model.get_topic_info()
print("\nImproved Topic Information:")
print(topic_info.head(10))

# Print topics with their new labels
print("\nTopik Pembicaraan Masyarakat terhadap Pasangan Prabowo-Gibran:")
for index, row in topic_info.iterrows():
    if row["Topic"] != -1:  # Skip outlier topic
        topic_id = row["Topic"]
        words = [word[0] for word in topic_model.get_topic(topic_id)[:8]]
        print(f"Theme: {row['Name']}")
        print(f"Keywords: {', '.join(words)}")
        print(f"Document count: {row['Count']}")
        print("-" * 50)

# Create a topic distribution visualization
plt.figure(figsize=(12, 6))
topic_counts = topic_info[topic_info["Topic"] != -1]["Count"]
topic_names = [label for topic, label in topic_labels.items() if topic != -1][:len(topic_counts)]

# Plot with better color scheme
bars = plt.bar(topic_names, topic_counts, color=plt.cm.viridis(np.linspace(0, 1, len(topic_counts))))

# Add count labels on top of bars
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height + 0.5,
            f'{int(height)}', ha='center', va='bottom', fontweight='bold')

plt.xticks(rotation=45, ha="right")
plt.title("Distribusi Topik Pembicaraan Masyarakat Terhadap Pasangan Prabowo-Gibran", fontsize=14, fontweight='bold')
plt.xlabel("Topik Pembicaraan", fontsize=12)
plt.ylabel("Number of Tweets", fontsize=12)
plt.tight_layout()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# Display interactive visualizations
intertopic_map = topic_model.visualize_topics()
display(intertopic_map)

# Create hierarchical clustering visualization
hierarchy = topic_model.visualize_hierarchy()
display(hierarchy)

# Create heatmap of topic similarities
heatmap = topic_model.visualize_heatmap()
display(heatmap)

# Create word clouds for top 3 topics
plt.figure(figsize=(15, 10))
for i, topic_id in enumerate(topic_info[topic_info['Topic'] != -1]['Topic'][:3]):
    plt.subplot(1, 3, i+1)
    
    # Get topic words and weights
    words = dict(topic_model.get_topic(topic_id)[:15])
    
    # Create and display wordcloud
    wordcloud = WordCloud(width=400, height=400, background_color='white', 
                          colormap='viridis', max_words=50).generate_from_frequencies(words)
    
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.title(f"Topic: {topic_labels[topic_id]}", fontsize=12)
    plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# Improved Topic Information:
#    Topic  Count                                            Name  \
# 0     -1  38600  -1_dukung 02_pilih 02_calon 02_pasang calon 02
# 1      0  25911            0_agama_pilih 02_02 menang_dukung 02
# 2      1  14859        1_debat_politik_calon presiden_demokrasi
# 3      2  12480                  2_food_estate_food estate_satu
# 4      3   1186                  3_video_film_viral_lihat video
# 5      4    427           4_israel_palestina_dukung israel_gaza
# 6      5    310                5_strategi_anggar_proyek_efektif
# 7      6    157            6_ekonomi_tumbuh_infrastruktur_cipta
# 8      7    148          7_low back_low_back pain_low back pain
# 9      8    112                   8_edit_reformasi_02 edit_cape
#
#                      CustomName  \
# 0                       Outlier
# 1  agama & pilih 02 & 02 menang
# 2     Penampilan Pidato & Debat
# 3   food & estate & food estate
# 4          video & film & viral
# 5      Kampanye & Isu Palestina
# 6    strategi & anggar & proyek
# 7     Visi Ekonomi & Kemakmuran
# 8    low back & low & back pain
# 9    edit & reformasi & 02 edit
#
#                                       Representation  \
# 0  [dukung 02, pilih 02, calon 02, pasang calon 0...
# 1  [agama, pilih 02, 02 menang, dukung 02, calon ...
# 2  [debat, politik, calon presiden, demokrasi, wa...
# 3  [food, estate, food estate, satu, tentara, heb...
# 4  [video, film, viral, lihat video, porno, video...
# 5  [israel, palestina, dukung israel, gaza, tulis...
# 6  [strategi, anggar, proyek, efektif, jitu, cada...
# 7  [ekonomi, tumbuh, infrastruktur, cipta, cipta ...
# 8  [low back, low, back pain, low back pain, pain...
# 9  [edit, reformasi, 02 edit, cape, cape cape, or...
#
#                                  Representative_Docs
# 0  [drama pilih presiden seru sih calon calon pre...
# 1  [gedek banget anjing dikasitau jawab template ...
# 2  [tuju calon wakil presiden 02 etika sok alam a...
# 3  [prabowo mana komisi berantas korupsi diam dia...
# 4  [02 kacauu video wkwk, dukung pasang calon 02 ...
# 5  [generalisir dukung 02 profesional israel abu ...
# 6  [prabowo calon presiden cerdas strategi bagus,...
# 7  [apresiasi fokus prabowo kembang ekonomi kreat...
# 8  [kali sepakat opung low back pain pilih 02, lo...
# 9  [cape cape demo reformasi turun orde kejar kej...
#
# Topik Pembicaraan Masyarakat terhadap Pasangan Prabowo-Gibran:
# Theme: 0_agama_pilih 02_02 menang_dukung 02
# Keywords: agama, pilih 02, 02 menang, dukung 02, calon 02, pasang calon 02, buzzer 02, survei
# Document count: 25911
# --------------------------------------------------
# Theme: 1_debat_politik_calon presiden_demokrasi
# Keywords: debat, politik, calon presiden, demokrasi, wakil presiden, calon wakil presiden, calon wakil, wakil
# Document count: 14859
# --------------------------------------------------
# Theme: 2_food_estate_food estate_satu
# Keywords: food, estate, food estate, satu, tentara, hebat, tentara nasional, suara
# Document count: 12480
# --------------------------------------------------
# Theme: 3_video_film_viral_lihat video
# Keywords: video, film, viral, lihat video, porno, videotron, film dirty, dirty
# Document count: 1186
# --------------------------------------------------
# Theme: 4_israel_palestina_dukung israel_gaza
# Keywords: israel, palestina, dukung israel, gaza, tulis, profesional, janda, abu janda
# Document count: 427
# --------------------------------------------------
# Theme: 5_strategi_anggar_proyek_efektif
# Keywords: strategi, anggar, proyek, efektif, jitu, cadang, gaet, debat
# Document count: 310
# --------------------------------------------------
# Theme: 6_ekonomi_tumbuh_infrastruktur_cipta
# Keywords: ekonomi, tumbuh, infrastruktur, cipta, cipta lapang kerja, cipta lapang, lanjutgan, lapang kerja
# Document count: 157
# --------------------------------------------------
# Theme: 7_low back_low_back pain_low back pain
# Keywords: low back, low, back pain, low back pain, pain, minim, back, minimal
# Document count: 148
# --------------------------------------------------
# Theme: 8_edit_reformasi_02 edit_cape
# Keywords: edit, reformasi, 02 edit, cape, cape cape, orde, 02 rugi, kkn
# Document count: 112
# --------------------------------------------------
# Theme: 9_energi_hijau_positif_inspirasi
# Keywords: energi, hijau, positif, inspirasi, energi positif, optimis, semangat, ide
# Document count: 75
# --------------------------------------------------
# Theme: 10_sistem_sistem tahan_utama sistem tahan_utama sistem
# Keywords: sistem, sistem tahan, utama sistem tahan, utama sistem, alat utama, alat utama sistem, alat, utama
# Document count: 67
# --------------------------------------------------
# Theme: 11_direct message_message_direct_online
# Keywords: direct message, message, direct, online, ojek online, ojek, line, merdeka
# Document count: 41
# --------------------------------------------------
# Theme: 12_teori_konspirasi_praktik_handal
# Keywords: teori, konspirasi, praktik, handal, korea pop, pop, khayal, respek
# Document count: 26
# --------------------------------------------------
# Theme: 13_timor_bohong sih_santa_gbla
# Keywords: timor, bohong sih, santa, gbla, coba cari, tribun, kapasitas, hitung
# Document count: 11
# --------------------------------------------------

# %%
from wordcloud import WordCloud
import seaborn as sns

# %%
# Create topic distribution from the existing topic_info
topic_distribution = topic_info.set_index("Topic")["Count"]

# Get representative documents for key campaign themes
print("\nRepresentative tweets for key topic:")
key_topics = [t for t in topic_distribution.index if t != -1][:5]

for topic_id in key_topics:
    theme_name = topic_model.get_topic_info().loc[topic_model.get_topic_info()["Topic"] == topic_id, "Name"].values[0]
    print(f"\n--- Theme: {theme_name} ---")
    rep_docs = topic_model.get_representative_docs(topic_id)
    for i, doc in enumerate(rep_docs[:3]):
        print(f"{i+1}. {doc[:200]}...")
# Out:
# Representative tweets for key topic:
#
# --- Theme: 0_agama_pilih 02_02 menang_dukung 02 ---
# 1. gedek banget anjing dikasitau jawab template melulu pengaruh all in 02...
# 2. teman dukung 02 pas dicekokin fakta curang mungut suara oknum maksud anjengg...
# 3. prabowo alhamdulillah manusia dukung pasang calon 02 orang pintar kubu abu janda...
#
# --- Theme: 1_debat_politik_calon presiden_demokrasi ---
# 1. tuju calon wakil presiden 02 etika sok alam asudahlah karbitan...
# 2. prabowo prabowo saudara laki prabowo bersih main pas jabat calon presiden calon wakil presiden hancur hancur politik uang tolong hancur sistem demokrasi indonesia...
# 3. kader partai demokrat calon legislatif dewan wakil rakyat ri prof denny indrayana komentar calon presiden calon wakil presiden 02 beliau buka pintu makzul alas administratif akibat langgar etik berat ...
#
# --- Theme: 2_food_estate_food estate_satu ---
# 1. prabowo mana komisi berantas korupsi diam diam food estate prabowo...
# 2. prabowo selidik komisi berantas korupsi sih komisi berantas korupsi takut wiwi prabowo lapor ubeidillah badrun terima komisi berantas korupsi argumen dicari2 food estate beli alat utama sistem tahan i...
# 3. teman teman simak jelas pakar kait gagal food estate tanggung prabowo sama food estate tanam paksa zaman belanda pakar ipb papar alas buyar mimpi daulat pangan jokowi...
#
# --- Theme: 3_video_film_viral_lihat video ---
# 1. 02 kacauu video wkwk...
# 2. dukung pasang calon 02 panas semenjak film dirty pilih...
# 3. kerja bantu buzzer 02 panas tonton film dirty pilih...
#
# --- Theme: 4_israel_palestina_dukung israel_gaza ---
# 1. generalisir dukung 02 profesional israel abu janda profesional israel...
# 2. prabowo bela palestina berita kerja israel...
# 3. salah israel dukung israel posisi israel jajah curi rumah rumah warga palestina prabowo paham israel palestina parah...
