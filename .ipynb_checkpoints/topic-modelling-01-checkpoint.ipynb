# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from bertopic import BERTopic
from bertopic.vectorizers import ClassTfidfTransformer
from bertopic.dimensionality import BaseDimensionalityReduction
from sklearn.feature_extraction.text import CountVectorizer
from cuml.manifold import UMAP
from cuml.cluster import HDBSCAN
from sentence_transformers import SentenceTransformer

# %%
df_01 = pd.read_csv('data/stemmed_merged_kubu_01.csv')
df_02 = pd.read_csv('data/stemmed_merged_kubu_02.csv')
df_03 = pd.read_csv('data/stemmed_merged_kubu_03.csv')

# %%
indo_stopwords = [
    # Basic Indonesian stopwords (keep these)
    "yang", "dan", "di", "dengan", "untuk", "dari", "ke", "pada", "ini", "itu",
    "atau", "ada", "juga", "dalam", "saya", "kamu", "anda", "mereka", "kita", "kami",
    "dia", "nya", "adalah", "akan", "oleh", "seperti", "telah", "sudah", "bisa", "dapat",
    "tidak", "tak", "jangan", "ya", "via", "yg", "dgn", "utk", "dr", "pd", "dlm", "sdh", "tdk", "kaya", "kayak", 
    
    # All candidate names and variations (since they appear everywhere)
    "anies", "baswedan", "rasyid", "muhaimin", "iskandar", "cak", "imin", "gus", 
    "prabowo", "subianto", "gibran", "rakabuming", "raka", "ganjar", "pranowo", 
    "mahfud", "md", "gama", "mawi", "abdurrahman", "abdul", "amin"
    
    # Titles and name prefixes
    "mas", "pak", "bu", "bapak", "ibu", "om", "tante", "mbak", "bro", "sis", "bang", 
    "abang", "kak", "adek", "adik", "kakak", "bung", "prof", "dr", "haji", "hajah", "h",
    
    # Social media expressions
    "rt", "dm", "pm", "cc", "wkwk", "haha", "woi", "hey", "ah", "eh", "oh", "hmm", "btw",
    "omg", "lol", "sih", "aja", "gitu", "banget", "kok", "deh", "ih", "yuk", "mantap",
    "insya", "insyaallah", "alhamdulillah", "bismillah", "amin", "allahuma", "allah",
    
    # Locations
    "jakarta", "jawa", "barat", "timur", "tengah", "utara", "selatan", "sumatra", "bali", 
    "aceh", "kota", "desa", "daerah", "wilayah", "provinsi", "kabupaten", "kawasan",
    "bandung", "surabaya", "makassar", "balikpapan", "semarang", "yogyakarta", "solo",
]

# %%
vectorizer = CountVectorizer(
    stop_words=indo_stopwords,
    ngram_range=(1, 3),  # Keep bigrams and trigrams for political phrases
    min_df=5,            # Lower threshold to capture more specific topics
    max_df=0.7           # Stricter upper bound to remove very common terms
)

# Configure UMAP for better clustering of political content
umap_model = UMAP(
    n_neighbors=15,      # Smaller neighborhood for more specific clusters
    n_components=5,      
    min_dist=0.0,        # Adjusted for better separation
    metric='cosine',
    random_state=42
)

# More sensitive clustering for political topics
hdbscan_model = HDBSCAN(
    min_cluster_size=10,  # Smaller clusters to capture specific campaign themes
    min_samples=5,       # More lenient sample requirement
    metric='euclidean',
    cluster_selection_method='eom',
    prediction_data=True
)

# Improved c-TF-IDF weighting
ctfidf_model = ClassTfidfTransformer(
    reduce_frequent_words=True,
    bm25_weighting=True
)

embedding_model = SentenceTransformer(
    'distiluse-base-multilingual-cased-v1'
)

# Configure BERTopic for Indonesian political content
topic_model = BERTopic(
    language="multilingual",  # Keep multilingual for Indonesian
    calculate_probabilities=True,
    verbose=True,
    nr_topics=15,             # Reduced from 15 to get more focused topics
    min_topic_size=5,         # Smaller topics to capture campaign themes
    umap_model=umap_model,
    hdbscan_model=hdbscan_model,
    ctfidf_model=ctfidf_model,
    vectorizer_model=vectorizer,
    embedding_model=embedding_model,
)


# Fit the model
topics, probs = topic_model.fit_transform(df_01['full_text'].tolist())
# Out:
# [2025-06-02 15:27:30.036] [CUML] [info] build_algo set to brute_force_knn because random_state is given
# 2025-06-02 15:27:34,138 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches:   0%|          | 0/934 [00:00<?, ?it/s]
# 2025-06-02 15:27:40,600 - BERTopic - Embedding - Completed ✓
# 2025-06-02 15:27:40,601 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2025-06-02 15:27:41,119 - BERTopic - Dimensionality - Completed ✓
# 2025-06-02 15:27:41,120 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2025-06-02 15:27:41,998 - BERTopic - Cluster - Completed ✓
# 2025-06-02 15:27:41,999 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 2025-06-02 15:27:42,414 - BERTopic - Representation - Completed ✓
# 2025-06-02 15:27:42,415 - BERTopic - Topic reduction - Reducing number of topics
# 2025-06-02 15:27:42,857 - BERTopic - Topic reduction - Reduced number of topics from 173 to 15

# %%
# Generate more intuitive topic labels
topic_labels = {}
for topic_id in topic_model.get_topic_info()["Topic"]:
    if topic_id == -1:
        topic_labels[topic_id] = "outlier"
        continue
        
    # Get top words
    words = [word for word, _ in topic_model.get_topic(topic_id)[:5]]
    
    # Map topics to campaign themes based on keywords
    if any(term in words for term in ["palestina", "doa", "gelar", "bukittinggi"]):
        topic_labels[topic_id] = "Kampanye Palestina"
    elif any(term in words for term in ["aceh", "warga", "sambut", "bandara", "kedatagan"]):
        topic_labels[topic_id] = "Kunjungan ke Aceh"
    elif any(term in words for term in ["sumbar", "sumatra", "barat", "safari"]):
        topic_labels[topic_id] = "Kampanye Sumatra Barat"
    elif any(term in words for term in ["adil", "makmur", "sejahtera", "rakyat"]):
        topic_labels[topic_id] = "Visi Keadilan & Kemakmuran"
    elif any(term in words for term in ["menang", "indonesia", "senang", "bismillah"]):
        topic_labels[topic_id] = "Dukungan Kemenangan"
    elif any(term in words for term in ["pesantren", "santri", "tenanan", "kiai"]):
        topic_labels[topic_id] = "Dukungan Pesantren & Santri"
    elif any(term in words for term in ["partai", "bangkit", "bangsa"]):
        topic_labels[topic_id] = "Dukungan Partai Politik"
    else:
        # Use top 3 words as label for other topics
        topic_labels[topic_id] = " & ".join(words[:3])

# Apply custom labels
topic_model.set_topic_labels(topic_labels)

# %%
from wordcloud import WordCloud

# %%
# Get the improved topic information
topic_info = topic_model.get_topic_info()
print("\nImproved Topic Information:")
print(topic_info.head(10))

# Print topics with their new labels
print("\Topik Pembicaraan Masyarakat terhadap Pasangan Anies-Cak Imin:")
for index, row in topic_info.iterrows():
    if row["Topic"] != -1:  # Skip outlier topic
        topic_id = row["Topic"]
        words = [word[0] for word in topic_model.get_topic(topic_id)[:8]]
        print(f"Theme: {row['Name']}")
        print(f"Keywords: {', '.join(words)}")
        print(f"Document count: {row['Count']}")
        print("-" * 50)

# Create a topic distribution visualization
plt.figure(figsize=(12, 6))
topic_counts = topic_info[topic_info["Topic"] != -1]["Count"]
topic_names = [label for topic, label in topic_labels.items() if topic != -1][:len(topic_counts)]

# Plot with better color scheme
bars = plt.bar(topic_names, topic_counts, color=plt.cm.viridis(np.linspace(0, 1, len(topic_counts))))

# Add count labels on top of bars
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height + 0.5,
            f'{int(height)}', ha='center', va='bottom', fontweight='bold')

plt.xticks(rotation=45, ha="right")
plt.title("Distribusi Topik Pembicaraan Masyarakat terhadap Pasangan Anies-Cak Imin", fontsize=14, fontweight='bold')
plt.xlabel("Topik Pembicaraan", fontsize=12)
plt.ylabel("Number of Tweets", fontsize=12)
plt.tight_layout()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# Display interactive visualizations
intertopic_map = topic_model.visualize_topics()
display(intertopic_map)

# Create hierarchical clustering visualization
hierarchy = topic_model.visualize_hierarchy()
display(hierarchy)

# Create heatmap of topic similarities
heatmap = topic_model.visualize_heatmap()
display(heatmap)

# Create word clouds for top 3 topics
plt.figure(figsize=(15, 10))
for i, topic_id in enumerate(topic_info[topic_info['Topic'] != -1]['Topic'][:3]):
    plt.subplot(1, 3, i+1)
    
    # Get topic words and weights
    words = dict(topic_model.get_topic(topic_id)[:15])
    
    # Create and display wordcloud
    wordcloud = WordCloud(width=400, height=400, background_color='white', 
                          colormap='viridis', max_words=50).generate_from_frequencies(words)
    
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.title(f"Topic: {topic_labels[topic_id]}", fontsize=12)
    plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# Improved Topic Information:
#    Topic  Count                                               Name  \
# 0     -1  12691        -1_buzzer_calon 01_pilih 01_pasang calon 01
# 1      0   8105                  0_pilih 01_01 menang_suara_pintar
# 2      1   4801  1_pilih presiden_sambut_menang pilih presiden_...
# 3      2   2019               2_politik_indonesia_demokrasi_partai
# 4      3   1462         3_debat_kritik_dialog_calon wakil presiden
# 5      4    244                4_twitter_berita_media_media sosial
# 6      5    155            5_program_program kerja_program 01_misi
# 7      6    133                         6_israel_merdeka_aksi_free
# 8      7     70                 7_korea pop_korea_pop_play station
# 9      8     63                         8_live_respons_foto_respon
#
#                              CustomName  \
# 0                               outlier
# 1          pilih 01 & 01 menang & suara
# 2                     Kunjungan ke Aceh
# 3                   Dukungan Kemenangan
# 4               debat & kritik & dialog
# 5              twitter & berita & media
# 6  program & program kerja & program 01
# 7               israel & merdeka & aksi
# 8               korea pop & korea & pop
# 9                 live & respons & foto
#
#                                       Representation  \
# 0  [buzzer, calon 01, pilih 01, pasang calon 01, ...
# 1  [pilih 01, 01 menang, suara, pintar, pasang ca...
# 2  [pilih presiden, sambut, menang pilih presiden...
# 3  [politik, indonesia, demokrasi, partai, identi...
# 4  [debat, kritik, dialog, calon wakil presiden, ...
# 5  [twitter, berita, media, media sosial, baca be...
# 6  [program, program kerja, program 01, misi, vis...
# 7  [israel, merdeka, aksi, free, bela, monas, gaz...
# 8  [korea pop, korea, pop, play station, station,...
# 9  [live, respons, foto, respon, reaksi, positif,...
#
#                                  Representative_Docs
# 0  [berani sumpah sesuai ajar agama anut terima b...
# 1  [tt informasi isu bohong 01 sebar influencer i...
# 2  [desak anies bandung full bukti anak muda mile...
# 3  [ketua partai pegang partai demokrasi indonesi...
# 4  [muhaimin iskandar alias cak imin kritik progr...
# 5  [dukung 01 pusing naik nama anies media sosial...
# 6  [invertasi padat karya serap tenaga kerja loka...
# 7  [free palestina orasi anies baswedan bangkit s...
# 8  [beda ono pakai grup korea pop 01 kpopfication...
# 9  [respons cak imin copot ketua urus wilayah nah...
# \Topik Pembicaraan Masyarakat terhadap Pasangan Anies-Cak Imin:
# Theme: 0_pilih 01_01 menang_suara_pintar
# Keywords: pilih 01, 01 menang, suara, pintar, pasang calon 01, calon 01, presiden 01, 01 01
# Document count: 8105
# --------------------------------------------------
# Theme: 1_pilih presiden_sambut_menang pilih presiden_wakil
# Keywords: pilih presiden, sambut, menang pilih presiden, wakil, menang pilih, wakil presiden, pimpin, ri
# Document count: 4801
# --------------------------------------------------
# Theme: 2_politik_indonesia_demokrasi_partai
# Keywords: politik, indonesia, demokrasi, partai, identitas, nasional, legislatif, juang
# Document count: 2019
# --------------------------------------------------
# Theme: 3_debat_kritik_dialog_calon wakil presiden
# Keywords: debat, kritik, dialog, calon wakil presiden, calon wakil, komentar, wakil presiden, wakil
# Document count: 1462
# --------------------------------------------------
# Theme: 4_twitter_berita_media_media sosial
# Keywords: twitter, berita, media, media sosial, baca berita, sosial, tiktok, twit
# Document count: 244
# --------------------------------------------------
# Theme: 5_program_program kerja_program 01_misi
# Keywords: program, program kerja, program 01, misi, visi misi, visi, tenaga kerja, ibukota
# Document count: 155
# --------------------------------------------------
# Theme: 6_israel_merdeka_aksi_free
# Keywords: israel, merdeka, aksi, free, bela, monas, gaza, orasi
# Document count: 133
# --------------------------------------------------
# Theme: 7_korea pop_korea_pop_play station
# Keywords: korea pop, korea, pop, play station, station, fandom, play, kpopers
# Document count: 70
# --------------------------------------------------
# Theme: 8_live_respons_foto_respon
# Keywords: live, respons, foto, respon, reaksi, positif, lihat foto, live tiktok
# Document count: 63
# --------------------------------------------------
# Theme: 9_viral_viralkan_jelek 01_angkut
# Keywords: viral, viralkan, jelek 01, angkut, zaman, putri, etik, kagum
# Document count: 44
# --------------------------------------------------
# Theme: 10_food estate_estate_food_gratis
# Keywords: food estate, estate, food, gratis, makan siang, siang, blak, tani
# Document count: 33
# --------------------------------------------------
# Theme: 11_message_humanies_masak_pikir kritis
# Keywords: message, humanies, masak, pikir kritis, nazar, army, peang, ajak
# Document count: 15
# --------------------------------------------------
# Theme: 12_polisi_sektor_tertib_laksana
# Keywords: polisi, sektor, tertib, laksana, bina, aman, lurah, camat
# Document count: 14
# --------------------------------------------------
# Theme: 13_undang_informasi_undang undang_kena
# Keywords: undang, informasi, undang undang, kena, peang, maki maki, data data, revisi undang
# Document count: 12
# --------------------------------------------------

# %%
from wordcloud import WordCloud
import seaborn as sns

# %%
# Create topic distribution from the existing topic_info
topic_distribution = topic_info.set_index("Topic")["Count"]

# Get representative documents for key campaign themes
print("\nRepresentative tweets for key campaign themes:")
key_topics = [t for t in topic_distribution.index if t != -1][:5]

for topic_id in key_topics:
    theme_name = topic_model.get_topic_info().loc[topic_model.get_topic_info()["Topic"] == topic_id, "Name"].values[0]
    print(f"\n--- Theme: {theme_name} ---")
    rep_docs = topic_model.get_representative_docs(topic_id)
    for i, doc in enumerate(rep_docs[:3]):
        print(f"{i+1}. {doc[:200]}...")
# Out:
# Representative tweets for key campaign themes:
#
# --- Theme: 0_pilih 01_01 menang_suara_pintar ---
# 1. tt informasi isu bohong 01 sebar influencer ikut sebar data data fitnah potongan2 video berita sumber kredibel masif gibran resmi umum calon wakil presiden prabowo...
# 2. orang kesini sehat sebar benci pasang calon presiden calon wakil presiden 01 moga cepat sembuh minimal parah sakit...
# 3. bu dok kampanye model jalan x model makan wrga pesbuk please dok fokus visi misi pasang calon isu bohong fakta wrga x pintar memilah2 informasi fokus visi misi gagas 01 ilg suara...
#
# --- Theme: 1_pilih presiden_sambut_menang pilih presiden_wakil ---
# 1. desak anies bandung full bukti anak muda milenial butuh pimpin visi misi gimmick aktivis tulen santri tulen gubernur baik bro lawan serius tenang tuntas solusi gagas karya bijak adil makmur...
# 2. calon wakil presiden calon wakil presiden koalisi ubah muhaimin iskandar akrab sapa cak imin janji rakyat miskin cukup pilih anies baswedan pimpin dukung kerja keras rawan...
# 3. calon wakil presiden calon wakil presiden koalisi ubah muhaimin iskandar cak imin aku cap profesional lantar putus undur jabat wakil ketua dewan wakil rakyat ri sibuk agenda kampanye...
#
# --- Theme: 2_politik_indonesia_demokrasi_partai ---
# 1. ketua partai pegang partai demokrasi indonesia juang partai bangkit bangsa megawati cak imin...
# 2. survei kalah menang pilih banding partai bangkit bangsa nasional demokrat partai adil sejahtera kader fokus anies...
# 3. coba serang 01 kayak suara counter abang pilih calon legislatif partai demokrasi indonesia juang coblos partai adil sejahtera konsisten...
#
# --- Theme: 3_debat_kritik_dialog_calon wakil presiden ---
# 1. muhaimin iskandar alias cak imin kritik program food estate kritik lontar pidato debat calon wakil presiden malam debat seru saksi...
# 2. twitkan kritik cak imin pasca debat calon wakil presiden nggampangke forum debat buruk malam lihat tolak menteri...
# 3. debat pilih presiden pribadi bagus anies kali debat calon wakil presiden menang gibran...
#
# --- Theme: 4_twitter_berita_media_media sosial ---
# 1. dukung 01 pusing naik nama anies media sosial tiktok prabowo instagram prabowo twitter prabowo burung hantu...
# 2. pakar media sosial puyeng kalah buzzer bot calon presiden 01 strategi khusus media sosial bisa insight lejit terus kunci natural interaktif agam x twitter tiktok instagram anies bubble...
# 3. dukung 01 tolog buk sebar isu bohong laku pilih damai serang pslon berita isu bohong baca berita minimal isi berita judul...
