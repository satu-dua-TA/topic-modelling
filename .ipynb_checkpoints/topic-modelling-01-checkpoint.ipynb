# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from bertopic import BERTopic
from bertopic.vectorizers import ClassTfidfTransformer
from bertopic.dimensionality import BaseDimensionalityReduction
from sklearn.feature_extraction.text import CountVectorizer
from cuml.manifold import UMAP
from cuml.cluster import HDBSCAN
from sentence_transformers import SentenceTransformer

# %%
df_01 = pd.read_csv('data/stemmed_merged_kubu_01.csv')
df_02 = pd.read_csv('data/stemmed_merged_kubu_02.csv')
df_03 = pd.read_csv('data/stemmed_merged_kubu_03.csv')

# %%
indo_stopwords = [
    # Basic Indonesian stopwords (keep these)
    "yang", "dan", "di", "dengan", "untuk", "dari", "ke", "pada", "ini", "itu",
    "atau", "ada", "juga", "dalam", "saya", "kamu", "anda", "mereka", "kita", "kami",
    "dia", "nya", "adalah", "akan", "oleh", "seperti", "telah", "sudah", "bisa", "dapat",
    "tidak", "tak", "jangan", "ya", "via", "yg", "dgn", "utk", "dr", "pd", "dlm", "sdh", "tdk", "kaya", "kayak", 
    
    # All candidate names and variations (since they appear everywhere)
    "anies", "baswedan", "rasyid", "muhaimin", "iskandar", "cak", "imin", "gus", 
    "prabowo", "subianto", "gibran", "rakabuming", "raka", "ganjar", "pranowo", 
    "mahfud", "md", "gama", "mawi", "abdurrahman", "abdul", "amin"
    
    # Titles and name prefixes
    "mas", "pak", "bu", "bapak", "ibu", "om", "tante", "mbak", "bro", "sis", "bang", 
    "abang", "kak", "adek", "adik", "kakak", "bung", "prof", "dr", "haji", "hajah", "h",
    
    # Social media expressions
    "rt", "dm", "pm", "cc", "wkwk", "haha", "woi", "hey", "ah", "eh", "oh", "hmm", "btw",
    "omg", "lol", "sih", "aja", "gitu", "banget", "kok", "deh", "ih", "yuk", "mantap",
    "insya", "insyaallah", "alhamdulillah", "bismillah", "amin", "allahuma", "allah",
    
    # Locations
    "jakarta", "jawa", "barat", "timur", "tengah", "utara", "selatan", "sumatra", "bali", 
    "aceh", "kota", "desa", "daerah", "wilayah", "provinsi", "kabupaten", "kawasan",
    "bandung", "surabaya", "makassar", "balikpapan", "semarang", "yogyakarta", "solo",
]

# %%
vectorizer = CountVectorizer(
    stop_words=indo_stopwords,
    ngram_range=(1, 3),  # Keep bigrams and trigrams for political phrases
    min_df=5,            # Lower threshold to capture more specific topics
    max_df=0.7           # Stricter upper bound to remove very common terms
)

# Configure UMAP for better clustering of political content
umap_model = UMAP(
    n_neighbors=15,      # Smaller neighborhood for more specific clusters
    n_components=5,      
    min_dist=0.0,        # Adjusted for better separation
    metric='cosine',
    random_state=42
)

# More sensitive clustering for political topics
hdbscan_model = HDBSCAN(
    min_cluster_size=10,  # Smaller clusters to capture specific campaign themes
    min_samples=5,       # More lenient sample requirement
    metric='euclidean',
    cluster_selection_method='eom',
    prediction_data=True
)

# Improved c-TF-IDF weighting
ctfidf_model = ClassTfidfTransformer(
    reduce_frequent_words=True,
    bm25_weighting=True
)

embedding_model = SentenceTransformer(
    'distiluse-base-multilingual-cased-v1'
)

# Configure BERTopic for Indonesian political content
topic_model = BERTopic(
    language="multilingual",  # Keep multilingual for Indonesian
    calculate_probabilities=True,
    verbose=True,
    nr_topics=15,             # Reduced from 15 to get more focused topics
    min_topic_size=5,         # Smaller topics to capture campaign themes
    umap_model=umap_model,
    hdbscan_model=hdbscan_model,
    ctfidf_model=ctfidf_model,
    vectorizer_model=vectorizer,
    embedding_model=embedding_model,
)


# Fit the model
topics, probs = topic_model.fit_transform(df_01['full_text'].tolist())
# Out:
# [2025-06-02 15:56:25.541] [CUML] [info] build_algo set to brute_force_knn because random_state is given
# 2025-06-02 15:56:29,752 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches:   0%|          | 0/934 [00:00<?, ?it/s]
# 2025-06-02 15:56:36,872 - BERTopic - Embedding - Completed ✓
# 2025-06-02 15:56:36,872 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2025-06-02 15:56:37,608 - BERTopic - Dimensionality - Completed ✓
# 2025-06-02 15:56:37,609 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2025-06-02 15:56:38,546 - BERTopic - Cluster - Completed ✓
# 2025-06-02 15:56:38,547 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 2025-06-02 15:56:38,977 - BERTopic - Representation - Completed ✓
# 2025-06-02 15:56:38,978 - BERTopic - Topic reduction - Reducing number of topics
# 2025-06-02 15:56:39,348 - BERTopic - Topic reduction - Reduced number of topics from 188 to 15

# %%
# Generate more intuitive topic labels
topic_labels = {}
for topic_id in topic_model.get_topic_info()["Topic"]:
    if topic_id == -1:
        topic_labels[topic_id] = "outlier"
        continue
        
    # Get top words
    words = [word for word, _ in topic_model.get_topic(topic_id)[:5]]
    
    # # Map topics to campaign themes based on keywords
    # if any(term in words for term in ["palestina", "doa", "gelar", "bukittinggi"]):
    #     topic_labels[topic_id] = "Kampanye Palestina"
    # elif any(term in words for term in ["aceh", "warga", "sambut", "bandara", "kedatagan"]):
    #     topic_labels[topic_id] = "Kunjungan ke Aceh"
    # elif any(term in words for term in ["sumbar", "sumatra", "barat", "safari"]):
    #     topic_labels[topic_id] = "Kampanye Sumatra Barat"
    # elif any(term in words for term in ["adil", "makmur", "sejahtera", "rakyat"]):
    #     topic_labels[topic_id] = "Visi Keadilan & Kemakmuran"
    # elif any(term in words for term in ["menang", "indonesia", "senang", "bismillah"]):
    #     topic_labels[topic_id] = "Dukungan Kemenangan"
    # elif any(term in words for term in ["pesantren", "santri", "tenanan", "kiai"]):
    #     topic_labels[topic_id] = "Dukungan Pesantren & Santri"
    # elif any(term in words for term in ["partai", "bangkit", "bangsa"]):
    #     topic_labels[topic_id] = "Dukungan Partai Politik"
    # else:
        # Use top 3 words as label for other topics
    topic_labels[topic_id] = " & ".join(words[:3])

# Apply custom labels
topic_model.set_topic_labels(topic_labels)

# %%
from wordcloud import WordCloud

# %%
# Get the improved topic information
topic_info = topic_model.get_topic_info()
print("\nImproved Topic Information:")
print(topic_info.head(10))

# Print topics with their new labels
print("\Topik Pembicaraan Masyarakat terhadap Pasangan Anies-Cak Imin:")
for index, row in topic_info.iterrows():
    if row["Topic"] != -1:  # Skip outlier topic
        topic_id = row["Topic"]
        words = [word[0] for word in topic_model.get_topic(topic_id)[:8]]
        print(f"Theme: {row['Name']}")
        print(f"Keywords: {', '.join(words)}")
        print(f"Document count: {row['Count']}")
        print("-" * 50)

# Create a topic distribution visualization
plt.figure(figsize=(12, 6))
topic_counts = topic_info[topic_info["Topic"] != -1]["Count"]
topic_names = [label for topic, label in topic_labels.items() if topic != -1][:len(topic_counts)]

# Plot with better color scheme
bars = plt.bar(topic_names, topic_counts, color=plt.cm.viridis(np.linspace(0, 1, len(topic_counts))))

# Add count labels on top of bars
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height + 0.5,
            f'{int(height)}', ha='center', va='bottom', fontweight='bold')

plt.xticks(rotation=45, ha="right")
plt.title("Distribusi Topik Pembicaraan Masyarakat terhadap Pasangan Anies-Cak Imin", fontsize=14, fontweight='bold')
plt.xlabel("Topik Pembicaraan", fontsize=12)
plt.ylabel("Number of Tweets", fontsize=12)
plt.tight_layout()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# Display interactive visualizations
intertopic_map = topic_model.visualize_topics()
display(intertopic_map)

# Create hierarchical clustering visualization
hierarchy = topic_model.visualize_hierarchy()
display(hierarchy)

# Create heatmap of topic similarities
heatmap = topic_model.visualize_heatmap()
display(heatmap)

# Create word clouds for top 3 topics
plt.figure(figsize=(15, 10))
for i, topic_id in enumerate(topic_info[topic_info['Topic'] != -1]['Topic'][:3]):
    plt.subplot(1, 3, i+1)
    
    # Get topic words and weights
    words = dict(topic_model.get_topic(topic_id)[:15])
    
    # Create and display wordcloud
    wordcloud = WordCloud(width=400, height=400, background_color='white', 
                          colormap='viridis', max_words=50).generate_from_frequencies(words)
    
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.title(f"Topic: {topic_labels[topic_id]}", fontsize=12)
    plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# Improved Topic Information:
#    Topic  Count                                          Name  \
# 0     -1  13801  -1_calon 01_buzzer_pasang calon 01_dukung 01
# 1      0   9454              0_debat_pilih 01_01 menang_video
# 2      1   4514      1_pilih presiden_ayah_indonesia_presiden
# 3      2   1187           2_politik_demokrasi_partai_nasional
# 4      3    373           3_twitter_media_berita_media sosial
# 5      4    156           4_program_program kerja_gratis_misi
# 6      5    125                    5_palestina_aksi_free_bela
# 7      6     89                6_kritik_respons_foto_komentar
# 8      7     43                  7_viral_viralkan_putri_resah
# 9      8     33                      8_data_luhut_tambang_adu
#
#                           CustomName  \
# 0                            outlier
# 1       debat & pilih 01 & 01 menang
# 2  pilih presiden & ayah & indonesia
# 3       politik & demokrasi & partai
# 4           twitter & media & berita
# 5   program & program kerja & gratis
# 6            palestina & aksi & free
# 7            kritik & respons & foto
# 8           viral & viralkan & putri
# 9             data & luhut & tambang
#
#                                       Representation  \
# 0  [calon 01, buzzer, pasang calon 01, dukung 01,...
# 1  [debat, pilih 01, 01 menang, video, pasang cal...
# 2  [pilih presiden, ayah, indonesia, presiden, wa...
# 3  [politik, demokrasi, partai, nasional, juang, ...
# 4  [twitter, media, berita, media sosial, sosial,...
# 5  [program, program kerja, gratis, misi, visi mi...
# 6  [palestina, aksi, free, bela, orasi, amerika, ...
# 7  [kritik, respons, foto, komentar, kampus, resp...
# 8  [viral, viralkan, putri, resah, instagram, akt...
# 9  [data, luhut, tambang, adu, pakar, bacot, edar...
#
#                                  Representative_Docs
# 0  [buka ruang dialog laden sepenuh hati bisa ped...
# 1  [kak lihat replies akun suka ngelempar isu doa...
# 2  [cak imin prof mahfud selamat gibran dicawapre...
# 3  [rumus didik jangkau peluang kerja luas pilih ...
# 4  [pikir media sosial banyak dukung 01 dukung si...
# 5  [program bahan bakar minyak gratis 01 kah hala...
# 6  [lapang medan merdeka anies kirim pesan merdek...
# 7  [kampus kritik jokowi cak imin ingat keras, ra...
# 8  [wajib viral sekolah cakep ampun sok flexing i...
# 9  [cak imin adu data tambang nikel luhut gibran ...
# \Topik Pembicaraan Masyarakat terhadap Pasangan Anies-Cak Imin:
# Theme: 0_debat_pilih 01_01 menang_video
# Keywords: debat, pilih 01, 01 menang, video, pasang calon 01, calon 01, pintar, pasang calon
# Document count: 9454
# --------------------------------------------------
# Theme: 1_pilih presiden_ayah_indonesia_presiden
# Keywords: pilih presiden, ayah, indonesia, presiden, wakil, wakil presiden, pimpin, sambut
# Document count: 4514
# --------------------------------------------------
# Theme: 2_politik_demokrasi_partai_nasional
# Keywords: politik, demokrasi, partai, nasional, juang, partai adil sejahtera, partai adil, partai bangkit bangsa
# Document count: 1187
# --------------------------------------------------
# Theme: 3_twitter_media_berita_media sosial
# Keywords: twitter, media, berita, media sosial, sosial, sosial media, baca berita, isu bohong
# Document count: 373
# --------------------------------------------------
# Theme: 4_program_program kerja_gratis_misi
# Keywords: program, program kerja, gratis, misi, visi misi, visi, tingkat, tenaga kerja
# Document count: 156
# --------------------------------------------------
# Theme: 5_palestina_aksi_free_bela
# Keywords: palestina, aksi, free, bela, orasi, amerika, kirim, allahu akbar
# Document count: 125
# --------------------------------------------------
# Theme: 6_kritik_respons_foto_komentar
# Keywords: kritik, respons, foto, komentar, kampus, respon, reaksi, jokowi
# Document count: 89
# --------------------------------------------------
# Theme: 7_viral_viralkan_putri_resah
# Keywords: viral, viralkan, putri, resah, instagram, aktivis, etik, baju
# Document count: 43
# --------------------------------------------------
# Theme: 8_data_luhut_tambang_adu
# Keywords: data, luhut, tambang, adu, pakar, bacot, edar, hilir
# Document count: 33
# --------------------------------------------------
# Theme: 9_food estate_estate_food_gratis
# Keywords: food estate, estate, food, gratis, makan siang, siang, blak, susu
# Document count: 32
# --------------------------------------------------
# Theme: 10_live_desak_semangat ayah_oposisi
# Keywords: live, desak, semangat ayah, oposisi, barusan, riau, youtube, live tiktok
# Document count: 15
# --------------------------------------------------
# Theme: 11_polisi_sektor_laksana_aman
# Keywords: polisi, sektor, laksana, aman, lurah, camat, rukun, jembatan
# Document count: 14
# --------------------------------------------------
# Theme: 12_message_masak_pikir kritis_nazar
# Keywords: message, masak, pikir kritis, nazar, online, bincang, instagram tiktok, tukar
# Document count: 14
# --------------------------------------------------
# Theme: 13_transaksi_informasi_undang_undang undang
# Keywords: transaksi, informasi, undang, undang undang, bot, india, akun, komen akun
# Document count: 11
# --------------------------------------------------

# %%
from wordcloud import WordCloud
import seaborn as sns

# %%
# Create topic distribution from the existing topic_info
topic_distribution = topic_info.set_index("Topic")["Count"]

# Get representative documents for key campaign themes
print("\nRepresentative tweets for key campaign themes:")
key_topics = [t for t in topic_distribution.index if t != -1][:5]

for topic_id in key_topics:
    theme_name = topic_model.get_topic_info().loc[topic_model.get_topic_info()["Topic"] == topic_id, "Name"].values[0]
    print(f"\n--- Theme: {theme_name} ---")
    rep_docs = topic_model.get_representative_docs(topic_id)
    for i, doc in enumerate(rep_docs[:3]):
        print(f"{i+1}. {doc[:200]}...")
# Out:
# Representative tweets for key campaign themes:
#
# --- Theme: 0_debat_pilih 01_01 menang_video ---
# 1. kak lihat replies akun suka ngelempar isu doang habis ban suruh kasih bukti langsung hilang bikin twit bilang dukung 01 suka keroyokan harga pilih orang lain...
# 2. gilir calon presiden 01 pas forum debat ngeritik bilang nyindiri2 melulu kerja sindir kayak uang orang jelek jelek pakai bahasa kasar muka kritik nama...
# 3. lepas debat calon presiden calon wakil presiden kemarin film dokumenter dirty pilih bilang ikut ulama pilih 01 hidup mudah 10thn harap depan better judge kafir sobat salam damai...
#
# --- Theme: 1_pilih presiden_ayah_indonesia_presiden ---
# 1. cak imin prof mahfud selamat gibran dicawapreskan etika presiden ri jabat restu anak maju calon presiden calon wakil presiden ngutak atik konstitusi mk tuai adik ipar lain ugm uii suara prihatin...
# 2. calon wakil presiden calon wakil presiden koalisi ubah muhaimin iskandar cak imin aku cap profesional lantar putus undur jabat wakil ketua dewan wakil rakyat ri sibuk agenda kampanye...
# 3. anies gus imin dukung rakyat indonesia menang pilih presiden partai bangkit bangsa 02 ri...
#
# --- Theme: 2_politik_demokrasi_partai_nasional ---
# 1. rumus didik jangkau peluang kerja luas pilih 01 tuju undang undang tpks pilih nasional demokrat partai bangkit bangsa inisiasi bang tobas nasional demokrat bu luluk partai bangkit bangsa tuju revisi u...
# 2. kampanye nasional demokrat partai bangkit bangsa partai adil sejahtera anies pilih presiden pilih legislatif menang...
# 3. coblos partai coblos calon legislatif patrtai nasional demokrat partai bangkit bangsa partai adil sejahtera koalisi calon presiden coblos pasang calon 01...
#
# --- Theme: 3_twitter_media_berita_media sosial ---
# 1. pikir media sosial banyak dukung 01 dukung sih genap pakai media sosial...
# 2. pakar media sosial puyeng kalah buzzer bot calon presiden 01 strategi khusus media sosial bisa insight lejit terus kunci natural interaktif agam x twitter tiktok instagram anies bubble...
# 3. dukung 01 pusing naik nama anies media sosial tiktok prabowo instagram prabowo twitter prabowo burung hantu...
#
# --- Theme: 4_program_program kerja_gratis_misi ---
# 1. program bahan bakar minyak gratis 01 kah halaman bahan bakar minyak gratis visi misi anies...
# 2. baca bang selagi standar ganda ngemengin program orang program 02 makan siang susu gratis anies daerah khusus ibukota owo sontek program cak imin daerah ditmbah 5m maju daerah std gnda diam...
# 3. salah visi misi amin anies selenggara perintah pihak rakyat amin cipta birokrasi profesional program program kerja...
