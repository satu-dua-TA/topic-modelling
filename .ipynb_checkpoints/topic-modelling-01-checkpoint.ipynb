# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from bertopic import BERTopic
from bertopic.vectorizers import ClassTfidfTransformer
from bertopic.dimensionality import BaseDimensionalityReduction
from sklearn.feature_extraction.text import CountVectorizer
from cuml.manifold import UMAP
from cuml.cluster import HDBSCAN
from sentence_transformers import SentenceTransformer

# %%
df_01 = pd.read_csv('data/stemmed_merged_kubu_01.csv')
df_02 = pd.read_csv('data/stemmed_merged_kubu_02.csv')
df_03 = pd.read_csv('data/stemmed_merged_kubu_03.csv')

# %%
indo_stopwords = [
    # Basic Indonesian stopwords (keep these)
    "yang", "dan", "di", "dengan", "untuk", "dari", "ke", "pada", "ini", "itu",
    "atau", "ada", "juga", "dalam", "saya", "kamu", "anda", "mereka", "kita", "kami",
    "dia", "nya", "adalah", "akan", "oleh", "seperti", "telah", "sudah", "bisa", "dapat",
    "tidak", "tak", "jangan", "ya", "via", "yg", "dgn", "utk", "dr", "pd", "dlm", "sdh", "tdk",
    
    # All candidate names and variations (since they appear everywhere)
    "anies", "baswedan", "rasyid", "muhaimin", "iskandar", "cak", "imin", "gus", 
    "prabowo", "subianto", "gibran", "rakabuming", "raka", "ganjar", "pranowo", 
    "mahfud", "md", "gama", "mawi", "abdurrahman", "abdul", "amin"
    
    # Titles and name prefixes
    "mas", "pak", "bu", "bapak", "ibu", "om", "tante", "mbak", "bro", "sis", "bang", 
    "abang", "kak", "adek", "adik", "kakak", "bung", "prof", "dr", "haji", "hajah", "h",
    
    # Social media expressions
    "rt", "dm", "pm", "cc", "wkwk", "haha", "woi", "hey", "ah", "eh", "oh", "hmm", "btw",
    "omg", "lol", "sih", "aja", "gitu", "banget", "kok", "deh", "ih", "yuk", "mantap",
    "insya", "insyaallah", "alhamdulillah", "bismillah", "amin", "allahuma", "allah",
    
    # Locations
    "jakarta", "jawa", "barat", "timur", "tengah", "utara", "selatan", "sumatra", "bali", 
    "aceh", "kota", "desa", "daerah", "wilayah", "provinsi", "kabupaten", "kawasan",
    "bandung", "surabaya", "makassar", "balikpapan", "semarang", "yogyakarta", "solo",
    
    

]

# %%
vectorizer = CountVectorizer(
    stop_words=indo_stopwords,
    ngram_range=(1, 3),  # Keep bigrams and trigrams for political phrases
    min_df=5,            # Lower threshold to capture more specific topics
    max_df=0.7           # Stricter upper bound to remove very common terms
)

# Configure UMAP for better clustering of political content
umap_model = UMAP(
    n_neighbors=15,      # Smaller neighborhood for more specific clusters
    n_components=5,      
    min_dist=0.0,        # Adjusted for better separation
    metric='cosine',
    random_state=42
)

# More sensitive clustering for political topics
hdbscan_model = HDBSCAN(
    min_cluster_size=10,  # Smaller clusters to capture specific campaign themes
    min_samples=5,       # More lenient sample requirement
    metric='euclidean',
    cluster_selection_method='eom',
    prediction_data=True
)

# Improved c-TF-IDF weighting
ctfidf_model = ClassTfidfTransformer(
    reduce_frequent_words=True,
    bm25_weighting=True
)

embedding_model = SentenceTransformer(
    'distiluse-base-multilingual-cased-v1'
)

# Configure BERTopic for Indonesian political content
topic_model = BERTopic(
    language="multilingual",  # Keep multilingual for Indonesian
    calculate_probabilities=True,
    verbose=True,
    nr_topics=15,             # Reduced from 15 to get more focused topics
    min_topic_size=5,         # Smaller topics to capture campaign themes
    umap_model=umap_model,
    hdbscan_model=hdbscan_model,
    ctfidf_model=ctfidf_model,
    vectorizer_model=vectorizer,
    embedding_model=embedding_model,
)


# Fit the model
topics, probs = topic_model.fit_transform(df_01['full_text'].tolist())
# Out:
# [2025-06-02 15:10:52.890] [CUML] [info] build_algo set to brute_force_knn because random_state is given
# 2025-06-02 15:10:56,297 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches:   0%|          | 0/934 [00:00<?, ?it/s]
# 2025-06-02 15:11:02,676 - BERTopic - Embedding - Completed ✓
# 2025-06-02 15:11:02,677 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2025-06-02 15:11:02,976 - BERTopic - Dimensionality - Completed ✓
# 2025-06-02 15:11:02,977 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2025-06-02 15:11:03,843 - BERTopic - Cluster - Completed ✓
# 2025-06-02 15:11:03,843 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 2025-06-02 15:11:04,256 - BERTopic - Representation - Completed ✓
# 2025-06-02 15:11:04,257 - BERTopic - Topic reduction - Reducing number of topics
# 2025-06-02 15:11:04,648 - BERTopic - Topic reduction - Reduced number of topics from 181 to 15

# %%
# Generate more intuitive topic labels
topic_labels = {}
for topic_id in topic_model.get_topic_info()["Topic"]:
    if topic_id == -1:
        topic_labels[topic_id] = "outlier"
        continue
        
    # Get top words
    words = [word for word, _ in topic_model.get_topic(topic_id)[:5]]
    
    # Map topics to campaign themes based on keywords
    if any(term in words for term in ["palestina", "doa", "gelar", "bukittinggi"]):
        topic_labels[topic_id] = "Kampanye Palestina"
    elif any(term in words for term in ["aceh", "warga", "sambut", "bandara", "kedatagan"]):
        topic_labels[topic_id] = "Kunjungan ke Aceh"
    elif any(term in words for term in ["sumbar", "sumatra", "barat", "safari"]):
        topic_labels[topic_id] = "Kampanye Sumatra Barat"
    elif any(term in words for term in ["adil", "makmur", "sejahtera", "rakyat"]):
        topic_labels[topic_id] = "Visi Keadilan & Kemakmuran"
    elif any(term in words for term in ["menang", "indonesia", "senang", "bismillah"]):
        topic_labels[topic_id] = "Dukungan Kemenangan"
    elif any(term in words for term in ["pesantren", "santri", "tenanan", "kiai"]):
        topic_labels[topic_id] = "Dukungan Pesantren & Santri"
    elif any(term in words for term in ["partai", "bangkit", "bangsa"]):
        topic_labels[topic_id] = "Dukungan Partai Politik"
    else:
        # Use top 3 words as label for other topics
        topic_labels[topic_id] = " & ".join(words[:3])

# Apply custom labels
topic_model.set_topic_labels(topic_labels)

# %%
from wordcloud import WordCloud

# %%
# Get the improved topic information
topic_info = topic_model.get_topic_info()
print("\nImproved Topic Information:")
print(topic_info.head(10))

# Print topics with their new labels
print("\Topik Pembicaraan Masyarakat terhadap Pasangan Anies-Cak Imin:")
for index, row in topic_info.iterrows():
    if row["Topic"] != -1:  # Skip outlier topic
        topic_id = row["Topic"]
        words = [word[0] for word in topic_model.get_topic(topic_id)[:8]]
        print(f"Theme: {row['Name']}")
        print(f"Keywords: {', '.join(words)}")
        print(f"Document count: {row['Count']}")
        print("-" * 50)

# Create a topic distribution visualization
plt.figure(figsize=(12, 6))
topic_counts = topic_info[topic_info["Topic"] != -1]["Count"]
topic_names = [label for topic, label in topic_labels.items() if topic != -1][:len(topic_counts)]

# Plot with better color scheme
bars = plt.bar(topic_names, topic_counts, color=plt.cm.viridis(np.linspace(0, 1, len(topic_counts))))

# Add count labels on top of bars
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height + 0.5,
            f'{int(height)}', ha='center', va='bottom', fontweight='bold')

plt.xticks(rotation=45, ha="right")
plt.title("Distribusi Topik Pembicaraan Masyarakat terhadap Pasangan Anies-Cak Imin", fontsize=14, fontweight='bold')
plt.xlabel("Topik Pembicaraan", fontsize=12)
plt.ylabel("Number of Tweets", fontsize=12)
plt.tight_layout()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# Display interactive visualizations
intertopic_map = topic_model.visualize_topics()
display(intertopic_map)

# Create hierarchical clustering visualization
hierarchy = topic_model.visualize_hierarchy()
display(hierarchy)

# Create heatmap of topic similarities
heatmap = topic_model.visualize_heatmap()
display(heatmap)

# Create word clouds for top 3 topics
plt.figure(figsize=(15, 10))
for i, topic_id in enumerate(topic_info[topic_info['Topic'] != -1]['Topic'][:3]):
    plt.subplot(1, 3, i+1)
    
    # Get topic words and weights
    words = dict(topic_model.get_topic(topic_id)[:15])
    
    # Create and display wordcloud
    wordcloud = WordCloud(width=400, height=400, background_color='white', 
                          colormap='viridis', max_words=50).generate_from_frequencies(words)
    
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.title(f"Topic: {topic_labels[topic_id]}", fontsize=12)
    plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# Improved Topic Information:
#    Topic  Count                                               Name  \
# 0     -1  13253     -1_dukung 01_calon 01_pasang calon 01_pilih 01
# 1      0   6283                  0_01 menang_suara_pintar_pilih 01
# 2      1   5131  1_pilih presiden_menang pilih presiden_sambut_...
# 3      2   3274           2_debat_politik_demokrasi_calon presiden
# 4      3    567             3_kayak_01 kayak_kayak 01_kayak dukung
# 5      4    480                  4_video_videotron_korea pop_korea
# 6      5    371                5_twitter_media_berita_media sosial
# 7      6    152    6_program_program 01_program kerja_misi program
# 8      7    127                    7_palestina_israel_merdeka_free
# 9      8     94                     8_kritik_respons_foto_komentar
#
#                              CustomName  \
# 0                               outlier
# 1            01 menang & suara & pintar
# 2                     Kunjungan ke Aceh
# 3           debat & politik & demokrasi
# 4           kayak & 01 kayak & kayak 01
# 5         video & videotron & korea pop
# 6              twitter & media & berita
# 7  program & program 01 & program kerja
# 8                    Kampanye Palestina
# 9               kritik & respons & foto
#
#                                       Representation  \
# 0  [dukung 01, calon 01, pasang calon 01, pilih 0...
# 1  [01 menang, suara, pintar, pilih 01, 01 01, ag...
# 2  [pilih presiden, menang pilih presiden, sambut...
# 3  [debat, politik, demokrasi, calon presiden, ca...
# 4  [kayak, 01 kayak, kayak 01, kayak dukung, kaya...
# 5  [video, videotron, korea pop, korea, pop, film...
# 6  [twitter, media, berita, media sosial, sosial,...
# 7  [program, program 01, program kerja, misi prog...
# 8  [palestina, israel, merdeka, free, aksi, bela,...
# 9  [kritik, respons, foto, komentar, lihat foto, ...
#
#                                  Representative_Docs
# 0  [potensi ubah undang undang badan usaha milik ...
# 1  [mas bicara kalah kubu 01 bicara duit relawan2...
# 2  [moga timnas data mungut suara wilayah minorit...
# 3  [maaf cak imin daerah suka basis partai bangki...
# 4  [considering 01 kayak, gunjing 01 kayak, dukun...
# 5  [pasang calon 01 kampanye resmi sebut satu gru...
# 6  [pakar media sosial puyeng kalah buzzer bot ca...
# 7  [nama metode kampanye visi misi program kerja ...
# 8  [lapang medan merdeka anies kirim pesan merdek...
# 9  [kampus ramai ramai kritik perintah cak imin l...
# \Topik Pembicaraan Masyarakat terhadap Pasangan Anies-Cak Imin:
# Theme: 0_01 menang_suara_pintar_pilih 01
# Keywords: 01 menang, suara, pintar, pilih 01, 01 01, agama, teman, dukung 01
# Document count: 6283
# --------------------------------------------------
# Theme: 1_pilih presiden_menang pilih presiden_sambut_bangsa
# Keywords: pilih presiden, menang pilih presiden, sambut, bangsa, maju, menang pilih, wakil, negara
# Document count: 5131
# --------------------------------------------------
# Theme: 2_debat_politik_demokrasi_calon presiden
# Keywords: debat, politik, demokrasi, calon presiden, calon wakil presiden, calon wakil, wakil presiden, presiden 01
# Document count: 3274
# --------------------------------------------------
# Theme: 3_kayak_01 kayak_kayak 01_kayak dukung
# Keywords: kayak, 01 kayak, kayak 01, kayak dukung, kayak dukung 01, orang kayak, kayak pilih, kayak orang
# Document count: 567
# --------------------------------------------------
# Theme: 4_video_videotron_korea pop_korea
# Keywords: video, videotron, korea pop, korea, pop, film, kpopers, play station
# Document count: 480
# --------------------------------------------------
# Theme: 5_twitter_media_berita_media sosial
# Keywords: twitter, media, berita, media sosial, sosial, direct message, direct, message
# Document count: 371
# --------------------------------------------------
# Theme: 6_program_program 01_program kerja_misi program
# Keywords: program, program 01, program kerja, misi program, visi misi program, visi misi, misi, visi
# Document count: 152
# --------------------------------------------------
# Theme: 7_palestina_israel_merdeka_free
# Keywords: palestina, israel, merdeka, free, aksi, bela, orasi, amerika
# Document count: 127
# --------------------------------------------------
# Theme: 8_kritik_respons_foto_komentar
# Keywords: kritik, respons, foto, komentar, lihat foto, respon, kampus, reaksi
# Document count: 94
# --------------------------------------------------
# Theme: 9_viral_ndas_bis_jelek 01
# Keywords: viral, ndas, bis, jelek 01, angkut, zaman, putri, resah
# Document count: 41
# --------------------------------------------------
# Theme: 10_food estate_estate_food_siang gratis
# Keywords: food estate, estate, food, siang gratis, gratis, makan siang, siang, blak
# Document count: 33
# --------------------------------------------------
# Theme: 11_sri_bukit_tan_bintang
# Keywords: sri, bukit, tan, bintang, ismail, kucing, sultan, pasar
# Document count: 23
# --------------------------------------------------
# Theme: 12_live_live tiktok_call_tik
# Keywords: live, live tiktok, call, tik, tik tok, join, barusan, riau
# Document count: 18
# --------------------------------------------------
# Theme: 13_polisi_sektor_tertib_laksana
# Keywords: polisi, sektor, tertib, laksana, bina, aman, rukun, lurah
# Document count: 14
# --------------------------------------------------

# %%
from wordcloud import WordCloud
import seaborn as sns

# %%
# Create topic distribution from the existing topic_info
topic_distribution = topic_info.set_index("Topic")["Count"]

# Get representative documents for key campaign themes
print("\nRepresentative tweets for key campaign themes:")
key_topics = [t for t in topic_distribution.index if t != -1][:5]

for topic_id in key_topics:
    theme_name = topic_model.get_topic_info().loc[topic_model.get_topic_info()["Topic"] == topic_id, "Name"].values[0]
    print(f"\n--- Theme: {theme_name} ---")
    rep_docs = topic_model.get_representative_docs(topic_id)
    for i, doc in enumerate(rep_docs[:3]):
        print(f"{i+1}. {doc[:200]}...")
# Out:
# Representative tweets for key campaign themes:
#
# --- Theme: 0_01 menang_suara_pintar_pilih 01 ---
# 1. mas bicara kalah kubu 01 bicara duit relawan2 prabowo bayar malag duit bicara anies gubernur smpyan kalah partai adil sejahtera ulama ulama profesional anies daerah khusus ibukota...
# 2. anies bukti surabaya kota pahlawan moga desak anies edisi lahir semangat lawan jujur down dengar bocor daerah anggap kantong suara 01 gembos mungut suara si komisi pemelihan...
# 3. bu dok kampanye model jalan x model makan wrga pesbuk please dok fokus visi misi pasang calon isu bohong fakta wrga x pintar memilah2 informasi fokus visi misi gagas 01 ilg suara...
#
# --- Theme: 1_pilih presiden_menang pilih presiden_sambut_bangsa ---
# 1. moga timnas data mungut suara wilayah minoritas hasil pilih gubernur daerah khusus ibukota signifikan banding pilih presiden duga signifikan anies terima kasih pilih manja...
# 2. calon wakil presiden koalisi ubah ketua partai bangkit bangsa partai bangkit bangsa muhaimin iskandar cak imin syukur dukung...
# 3. harap 01 putar pribadi anies alam kelola pemrov daerah khusus ibukota jakarta damai alam go internasional rangkul bawa indonesia tinggal landas negeri maju adil makmur sejahtera bahagia rakyat...
#
# --- Theme: 2_debat_politik_demokrasi_calon presiden ---
# 1. maaf cak imin daerah suka basis partai bangkit bangsa partai demokrasi indonesia juang suara dewan wakil rakyat sih oke xixixixi oh cak suara oaling mungut suara daerah xixixixxi...
# 2. bicara politik ah pasang 01 tarik anies bawa segar dunia politik runyam kaget pilih calon wakil presiden blunder suara jawa jawa timur partai bangkit bangsa...
# 3. calon presiden calon wakil presiden 01 bawa asa roasting dukung calon presiden calon wakil presiden...
#
# --- Theme: 3_kayak_01 kayak_kayak 01_kayak dukung ---
# 1. considering 01 kayak...
# 2. gunjing 01 kayak...
# 3. dukung 01 kayak mitos bang...
#
# --- Theme: 4_video_videotron_korea pop_korea ---
# 1. pasang calon 01 kampanye resmi sebut satu grup korea pop jadi seru seru kpopers bilang tunggang korea pop kak terang2nya sebut grup wajar fan grup terima takut disebut2...
# 2. fan base korea pop gede akun fan korea pop tumbang kena ras gara gara war korea pop lawan buzzer politik fan korea pop bawa bawa politik anies blunder bawa korea pop pilih presiden event politik besar...
# 3. mbak bikin konten gemar korea pop mbak suka grup xx bikin videotron 01 ngatasnamain kpopers mbak take down sih gara gara suka fandom kpopers dibawa2 panas2in mbak bilang lapor kali briefingnya...
