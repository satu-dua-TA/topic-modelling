# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from bertopic import BERTopic
from bertopic.vectorizers import ClassTfidfTransformer
from bertopic.dimensionality import BaseDimensionalityReduction
from sklearn.feature_extraction.text import CountVectorizer
from cuml.manifold import UMAP
from cuml.cluster import HDBSCAN
from sentence_transformers import SentenceTransformer

# %%
df_01 = pd.read_csv('data/stemmed_merged_kubu_01.csv')
df_02 = pd.read_csv('data/stemmed_merged_kubu_02.csv')
df_03 = pd.read_csv('data/stemmed_merged_kubu_03.csv')

# %%
indo_stopwords = [
    # Basic Indonesian stopwords (keep these)
    "yang", "dan", "di", "dengan", "untuk", "dari", "ke", "pada", "ini", "itu",
    "atau", "ada", "juga", "dalam", "saya", "kamu", "anda", "mereka", "kita", "kami",
    "dia", "nya", "adalah", "akan", "oleh", "seperti", "telah", "sudah", "bisa", "dapat",
    "tidak", "tak", "jangan", "ya", "via", "yg", "dgn", "utk", "dr", "pd", "dlm", "sdh", "tdk", "kaya", "kayak", 
    
    # All candidate names and variations (since they appear everywhere)
    "anies", "baswedan", "rasyid", "muhaimin", "iskandar", "cak", "imin", "gus", 
    "prabowo", "subianto", "gibran", "rakabuming", "raka", "ganjar", "pranowo", 
    "mahfud", "md", "gama", "mawi", "abdurrahman", "abdul", "amin"
    
    # Titles and name prefixes
    "mas", "pak", "bu", "bapak", "ibu", "om", "tante", "mbak", "bro", "sis", "bang", 
    "abang", "kak", "adek", "adik", "kakak", "bung", "prof", "dr", "haji", "hajah", "h",
    
    # Social media expressions
    "rt", "dm", "pm", "cc", "wkwk", "haha", "woi", "hey", "ah", "eh", "oh", "hmm", "btw",
    "omg", "lol", "sih", "aja", "gitu", "banget", "kok", "deh", "ih", "yuk", "mantap",
    "insya", "insyaallah", "alhamdulillah", "bismillah", "amin", "allahuma", "allah",
    
    # Locations
    "jakarta", "jawa", "barat", "timur", "tengah", "utara", "selatan", "sumatra", "bali", 
    "aceh", "kota", "desa", "daerah", "wilayah", "provinsi", "kabupaten", "kawasan",
    "bandung", "surabaya", "makassar", "balikpapan", "semarang", "yogyakarta", "solo",
]

# %%
vectorizer = CountVectorizer(
    stop_words=indo_stopwords,
    ngram_range=(1, 3),  # Keep bigrams and trigrams for political phrases
    min_df=5,            # Lower threshold to capture more specific topics
    max_df=0.7           # Stricter upper bound to remove very common terms
)

# Configure UMAP for better clustering of political content
umap_model = UMAP(
    n_neighbors=15,      # Smaller neighborhood for more specific clusters
    n_components=5,      
    min_dist=0.0,        # Adjusted for better separation
    metric='cosine',
    random_state=42
)

# More sensitive clustering for political topics
hdbscan_model = HDBSCAN(
    min_cluster_size=10,  # Smaller clusters to capture specific campaign themes
    min_samples=5,       # More lenient sample requirement
    metric='euclidean',
    cluster_selection_method='eom',
    prediction_data=True
)

# Improved c-TF-IDF weighting
ctfidf_model = ClassTfidfTransformer(
    reduce_frequent_words=True,
    bm25_weighting=True
)

embedding_model = SentenceTransformer(
    'distiluse-base-multilingual-cased-v1'
)

# Configure BERTopic for Indonesian political content
topic_model = BERTopic(
    language="multilingual",  # Keep multilingual for Indonesian
    calculate_probabilities=True,
    verbose=True,
    nr_topics=15,             # Reduced from 15 to get more focused topics
    min_topic_size=5,         # Smaller topics to capture campaign themes
    umap_model=umap_model,
    hdbscan_model=hdbscan_model,
    ctfidf_model=ctfidf_model,
    vectorizer_model=vectorizer,
    embedding_model=embedding_model,
)


# Fit the model
topics, probs = topic_model.fit_transform(df_01['full_text'].tolist())
# Out:
# [2025-06-02 16:55:23.545] [CUML] [info] build_algo set to brute_force_knn because random_state is given
# 2025-06-02 16:55:26,928 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches:   0%|          | 0/934 [00:00<?, ?it/s]
# 2025-06-02 16:55:34,287 - BERTopic - Embedding - Completed ✓
# 2025-06-02 16:55:34,288 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2025-06-02 16:55:34,622 - BERTopic - Dimensionality - Completed ✓
# 2025-06-02 16:55:34,623 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2025-06-02 16:55:35,812 - BERTopic - Cluster - Completed ✓
# 2025-06-02 16:55:35,813 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 2025-06-02 16:55:36,251 - BERTopic - Representation - Completed ✓
# 2025-06-02 16:55:36,251 - BERTopic - Topic reduction - Reducing number of topics
# 2025-06-02 16:55:36,696 - BERTopic - Topic reduction - Reduced number of topics from 179 to 15

# %%
# Generate more intuitive topic labels
topic_labels = {}
for topic_id in topic_model.get_topic_info()["Topic"]:
    if topic_id == -1:
        topic_labels[topic_id] = "outlier"
        continue
        
    # Get top words
    words = [word for word, _ in topic_model.get_topic(topic_id)[:5]]
    
    # Map topics to campaign themes based on keywords
    if any(term in words for term in ["palestina", "doa", "gelar", "bukittinggi"]):
        topic_labels[topic_id] = "Kampanye Palestina"
    elif any(term in words for term in ["aceh", "warga", "sambut", "bandara", "kedatagan"]):
        topic_labels[topic_id] = "Kunjungan ke Aceh"
    elif any(term in words for term in ["sumbar", "sumatra", "barat", "safari"]):
        topic_labels[topic_id] = "Kampanye Sumatra Barat"
    elif any(term in words for term in ["adil", "makmur", "sejahtera", "rakyat"]):
        topic_labels[topic_id] = "Visi Keadilan & Kemakmuran"
    elif any(term in words for term in ["menang", "indonesia", "senang", "bismillah"]):
        topic_labels[topic_id] = "Dukungan Kemenangan"
    elif any(term in words for term in ["pesantren", "santri", "tenanan", "kiai"]):
        topic_labels[topic_id] = "Dukungan Pesantren & Santri"
    elif any(term in words for term in ["partai", "bangkit", "bangsa"]):
        topic_labels[topic_id] = "Dukungan Partai Politik"
    else:
        # Use top 3 words as label for other topics
        topic_labels[topic_id] = " & ".join(words[:3])

# Apply custom labels
topic_model.set_topic_labels(topic_labels)

# %%
from wordcloud import WordCloud

# %%
# Get the improved topic information
topic_info = topic_model.get_topic_info()
print("\nImproved Topic Information:")
print(topic_info.head(10))

# Print topics with their new labels
print("\Topik Pembicaraan Masyarakat terhadap Pasangan Anies-Cak Imin:")
for index, row in topic_info.iterrows():
    if row["Topic"] != -1:  # Skip outlier topic
        topic_id = row["Topic"]
        words = [word[0] for word in topic_model.get_topic(topic_id)[:8]]
        print(f"Theme: {row['Name']}")
        print(f"Keywords: {', '.join(words)}")
        print(f"Document count: {row['Count']}")
        print("-" * 50)

# Create a topic distribution visualization
plt.figure(figsize=(12, 6))
topic_counts = topic_info[topic_info["Topic"] != -1]["Count"]
topic_names = [label for topic, label in topic_labels.items() if topic != -1][:len(topic_counts)]

# Plot with better color scheme
bars = plt.bar(topic_names, topic_counts, color=plt.cm.viridis(np.linspace(0, 1, len(topic_counts))))

# Add count labels on top of bars
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height + 0.5,
            f'{int(height)}', ha='center', va='bottom', fontweight='bold')

plt.xticks(rotation=45, ha="right")
plt.title("Distribusi Topik Pembicaraan Masyarakat terhadap Pasangan Anies-Cak Imin", fontsize=14, fontweight='bold')
plt.xlabel("Topik Pembicaraan", fontsize=12)
plt.ylabel("Number of Tweets", fontsize=12)
plt.tight_layout()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# Display interactive visualizations
intertopic_map = topic_model.visualize_topics()
display(intertopic_map)

# Create hierarchical clustering visualization
hierarchy = topic_model.visualize_hierarchy()
display(hierarchy)

# Create heatmap of topic similarities
heatmap = topic_model.visualize_heatmap()
display(heatmap)

# Create word clouds for top 3 topics
plt.figure(figsize=(15, 10))
for i, topic_id in enumerate(topic_info[topic_info['Topic'] != -1]['Topic'][:3]):
    plt.subplot(1, 3, i+1)
    
    # Get topic words and weights
    words = dict(topic_model.get_topic(topic_id)[:15])
    
    # Create and display wordcloud
    wordcloud = WordCloud(width=400, height=400, background_color='white', 
                          colormap='viridis', max_words=50).generate_from_frequencies(words)
    
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.title(f"Topic: {topic_labels[topic_id]}", fontsize=12)
    plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# Improved Topic Information:
#    Topic  Count                                             Name  \
# 0     -1  13593      -1_buzzer_calon 01_pasang calon 01_pilih 01
# 1      0   7149                0_01 menang_suara_pilih 01_pintar
# 2      1   3674   1_politik_calon presiden_presiden 01_demokrasi
# 3      2   3111                   2_sambut_ekonomi_warga_kampung
# 4      3   1447       3_debat_kritik_dialog_calon wakil presiden
# 5      4    369              4_twitter_media_berita_media sosial
# 6      5    160  5_program_program 01_program kerja_tenaga kerja
# 7      6    131                         6_merdeka_aksi_free_bela
# 8      7     75                     7_korea pop_korea_pop_fandom
# 9      8     40                     8_viral_jelek 01_zaman_putri
#
#                                CustomName  \
# 0                                 outlier
# 1            01 menang & suara & pilih 01
# 2  politik & calon presiden & presiden 01
# 3                       Kunjungan ke Aceh
# 4                 debat & kritik & dialog
# 5                twitter & media & berita
# 6    program & program 01 & program kerja
# 7                   merdeka & aksi & free
# 8                 korea pop & korea & pop
# 9                viral & jelek 01 & zaman
#
#                                       Representation  \
# 0  [buzzer, calon 01, pasang calon 01, pilih 01, ...
# 1  [01 menang, suara, pilih 01, pintar, pasang ca...
# 2  [politik, calon presiden, presiden 01, demokra...
# 3  [sambut, ekonomi, warga, kampung, pesantren, k...
# 4  [debat, kritik, dialog, calon wakil presiden, ...
# 5  [twitter, media, berita, media sosial, sosial,...
# 6  [program, program 01, program kerja, tenaga ke...
# 7  [merdeka, aksi, free, bela, orasi, amerika, ki...
# 8  [korea pop, korea, pop, fandom, kpopers, play ...
# 9  [viral, jelek 01, zaman, putri, etik, kagum, b...
#
#                                  Representative_Docs
# 0  [peduli ya orang pilih calon presiden serah de...
# 1  [hasil survei lembaga satu provinsi indonesia ...
# 2  [faktor calon wakil presiden 01 ketua partai b...
# 3  [lunas janji anies warga kampung bayam dampak ...
# 4  [debat calon wakil presiden malam calon wakil ...
# 5  [dukung 01 pusing naik nama anies media sosial...
# 6  [sarkasin program 01 gratis bahan bakar minyak...
# 7  [lapang medan merdeka monas anies rasyid baswe...
# 8  [kak saran benar tolong nama fandom korea pop ...
# 9  [sumpah we he twit jelek 01 takut viral, wajib...
# \Topik Pembicaraan Masyarakat terhadap Pasangan Anies-Cak Imin:
# Theme: 0_01 menang_suara_pilih 01_pintar
# Keywords: 01 menang, suara, pilih 01, pintar, pasang calon 01, calon 01, video, teman
# Document count: 7149
# --------------------------------------------------
# Theme: 1_politik_calon presiden_presiden 01_demokrasi
# Keywords: politik, calon presiden, presiden 01, demokrasi, pilih presiden, calon presiden 01, wakil presiden, partai
# Document count: 3674
# --------------------------------------------------
# Theme: 2_sambut_ekonomi_warga_kampung
# Keywords: sambut, ekonomi, warga, kampung, pesantren, khusus, pimpin, beliau
# Document count: 3111
# --------------------------------------------------
# Theme: 3_debat_kritik_dialog_calon wakil presiden
# Keywords: debat, kritik, dialog, calon wakil presiden, calon wakil, komentar, wakil presiden, pas debat
# Document count: 1447
# --------------------------------------------------
# Theme: 4_twitter_media_berita_media sosial
# Keywords: twitter, media, berita, media sosial, sosial, tiktok, judul, isu bohong
# Document count: 369
# --------------------------------------------------
# Theme: 5_program_program 01_program kerja_tenaga kerja
# Keywords: program, program 01, program kerja, tenaga kerja, misi, bagus, visi misi, khusus ibukota
# Document count: 160
# --------------------------------------------------
# Theme: 6_merdeka_aksi_free_bela
# Keywords: merdeka, aksi, free, bela, orasi, amerika, kirim, lemah
# Document count: 131
# --------------------------------------------------
# Theme: 7_korea pop_korea_pop_fandom
# Keywords: korea pop, korea, pop, fandom, kpopers, play station, station, play
# Document count: 75
# --------------------------------------------------
# Theme: 8_viral_jelek 01_zaman_putri
# Keywords: viral, jelek 01, zaman, putri, etik, kagum, baju, tempuh
# Document count: 40
# --------------------------------------------------
# Theme: 9_app_unduh_play_stadion
# Keywords: app, unduh, play, stadion, internasional, sepak bola, bola, sepak
# Document count: 36
# --------------------------------------------------
# Theme: 10_food estate_estate_food_gratis
# Keywords: food estate, estate, food, gratis, siang gratis, makan siang, siang, susu gratis
# Document count: 35
# --------------------------------------------------
# Theme: 11_live_desak_call_tik tok
# Keywords: live, desak, call, tik tok, tik, join, barusan, riau
# Document count: 15
# --------------------------------------------------
# Theme: 12_message_humanies_masak_pikir kritis
# Keywords: message, humanies, masak, pikir kritis, nazar, peang, spam, online
# Document count: 15
# --------------------------------------------------
# Theme: 13_transaksi_informasi_undang_undang undang
# Keywords: transaksi, informasi, undang, undang undang, bot, negara pakai, india, ubah salah
# Document count: 11
# --------------------------------------------------

# %%
from wordcloud import WordCloud
import seaborn as sns

# %%
# Create topic distribution from the existing topic_info
topic_distribution = topic_info.set_index("Topic")["Count"]

# Get representative documents for key campaign themes
print("\nRepresentative tweets for key campaign themes:")
key_topics = [t for t in topic_distribution.index if t != -1][:5]

for topic_id in key_topics:
    theme_name = topic_model.get_topic_info().loc[topic_model.get_topic_info()["Topic"] == topic_id, "Name"].values[0]
    print(f"\n--- Theme: {theme_name} ---")
    rep_docs = topic_model.get_representative_docs(topic_id)
    for i, doc in enumerate(rep_docs[:3]):
        print(f"{i+1}. {doc[:200]}...")
# Out:
# Representative tweets for key campaign themes:
#
# --- Theme: 0_01 menang_suara_pilih 01_pintar ---
# 1. hasil survei lembaga satu provinsi indonesia menang amin tidur ayo elemen rakyat indonesia mari bukti kuat menang pasang calon 01...
# 2. pasang calon 01 jual agama imam mahdi bodoh dukung dosa pilih anies mudah bodoh malaikat jibril tim sukses prestasi klaim prestasi kerja janji gudang tepat transportasi kaki sebab intoleran calon gube...
# 3. dukung 01 sumber daya manusia kualitas rendah terima nyata pilih kalah tanding isu isu bohong sebar fitnah tuduh curang sampah masyarakat...
#
# --- Theme: 1_politik_calon presiden_presiden 01_demokrasi ---
# 1. faktor calon wakil presiden 01 ketua partai bangkit bangsa gus imin signifikan amin lihat video muallim coker...
# 2. oke rumus calon presiden calon wakil presiden 01 dewan wakil rakyat partai buruh dewan wakil rakyat daerah buruh partai adil sejahtera dewan wakil daerah endang widuri...
# 3. suka partai adil sejahtera sih minim korupsi konsisten satu partai politik tolak undang undang ciptaker inklusif well apa partai demokrasi indonesia juang oposisi 01 menang...
#
# --- Theme: 2_sambut_ekonomi_warga_kampung ---
# 1. lunas janji anies warga kampung bayam dampak bangun jis nikmat janji anies selesai bangun rusun kampung bayam janji tepat pimpin sejati...
# 2. anies perintah daerah daerah khusus ibukota wenang zalim warga kampung bayam naudzubillah min dzalik...
# 3. warga kampung bayam langsung peluh anies menang lihat bentuk peduli anies rakyat warga kampung bayam huni anies gurbernur daerah khusus ibukota warga kampung bayam manusia tindas sulit...
#
# --- Theme: 3_debat_kritik_dialog_calon wakil presiden ---
# 1. debat calon wakil presiden malam calon wakil presiden nomor urut 01 muhaimin iskandar cak imin salah visi misi program cari solusi dunia tani indonesia cak imin hasil sensus tani badan pusat statistik...
# 2. ramai debat calon wakil presiden tiada mas anies rajut tenun bangsa lintas agama suku masyarakat kualitas calon presiden calon wakil presiden debat visi misi gagas dialog...
# 3. dukung 01 ngerujak cak imin pas debat calon wakil presiden kemarin terima kritik...
#
# --- Theme: 4_twitter_media_berita_media sosial ---
# 1. dukung 01 pusing naik nama anies media sosial tiktok prabowo instagram prabowo twitter prabowo burung hantu...
# 2. media sosial kolam 01 yaudaah ya wkwk...
# 3. buzzer 01 banget media sosial...
